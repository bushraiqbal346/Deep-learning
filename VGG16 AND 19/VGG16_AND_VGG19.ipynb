# %%
#cell 1
import os, json, datetime, warnings
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
from PIL import Image

os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, callbacks, optimizers, regularizers, Model
from sklearn.metrics import (
    classification_report, confusion_matrix, precision_recall_fscore_support,
)

warnings.filterwarnings("ignore")

# %%
#cell 2
# ── Mount Google Drive ──
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#cell 3
# ══════════════════════════════════════════════════════════════
# CONFIGURATION
# ══════════════════════════════════════════════════════════════
CONFIG = {
    #"dataset_path": "/content/drive/MyDrive/updated-dataset",
    #"output_dir": "/content/drive/MyDrive/OUTPUT",
    "dataset_path": "/content/drive/MyDrive/updated-dataset",
    "output_dir": "/content/drive/MyDrive/OUTPUT",
    "image_size": (224, 224),
    "num_channels": 3,
    "num_classes": 5,
    "class_names": [
        "Mild-Demented", "Moderate-Demented", "Non-Demented",
        "Severe-Demented", "Very-Mild-Demented",
    ],
    "batch_size": 32,
    "epochs": 20,
    # "epochs": 100,
    "initial_learning_rate": 1e-3,
    "min_learning_rate": 1e-7,
    "weight_decay": 5e-4,
    "dropout_fc1": 0.5,
    "dropout_fc2": 0.5,
    "label_smoothing": 0.1,
    "early_stopping_patience": 12,
    "reduce_lr_patience": 5,
    "reduce_lr_factor": 0.5,
    "seed": 42,
}

# ══════════════════════════════════════════════════════════════
# UTILITIES
# ══════════════════════════════════════════════════════════════

def set_seeds(seed):
    np.random.seed(seed)
    tf.random.set_seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)

def ensure_dir(path):
    os.makedirs(path, exist_ok=True)

def separator(title):
    print(f"\n{'═'*72}\n  {title}\n{'═'*72}")

# %%
#cell 4
# STAGE 1 — DATASET INSPECTION
# ══════════════════════════════════════════════════════════════
#
def inspect_dataset(config):
    separator("STAGE 1 — DATASET INSPECTION")
    base = config["dataset_path"]
    class_names = config["class_names"]
    summary = {}

    for split in ["train", "valid"]:
        split_path = os.path.join(base, split)
        if not os.path.isdir(split_path):
            print(f"  [WARNING] Missing: {split_path}")
            continue

        print(f"\n  Split: {split}")
        print(f"  {'Class':<25} {'Count':>6}  {'%':>8}")
        print(f"  {'-'*42}")

        class_counts = {}
        total = 0
        for cls in class_names:
            cls_path = os.path.join(split_path, cls)
            if not os.path.isdir(cls_path):
                class_counts[cls] = 0
                continue
            files = [f for f in os.listdir(cls_path)
                     if f.lower().endswith(('.jpg','.jpeg','.png'))]
            class_counts[cls] = len(files)
            total += len(files)

        for cls in class_names:
            cnt = class_counts.get(cls, 0)
            pct = (cnt / total * 100) if total > 0 else 0
            print(f"  {cls:<25} {cnt:>6}  {pct:>7.1f}%")
        print(f"  {'TOTAL':<25} {total:>6}")

        summary[split] = {"class_counts": class_counts, "total": total}

    return summary

# %%
# cell 5
# ══════════════════════════════════════════════════════════════
# STAGE 2 — EXPLORATORY DATA ANALYSIS
# ══════════════════════════════════════════════════════════════

def perform_eda(config, inspection_summary):
    separator("STAGE 2 — EDA")
    out = os.path.join(config["output_dir"], "eda")
    ensure_dir(out)
    class_names = config["class_names"]
    palette = sns.color_palette("viridis", n_colors=config["num_classes"])

    # Class distribution
    fig, axes = plt.subplots(1, 2, figsize=(14, 5))
    for idx, split in enumerate(["train", "valid"]):
        if split not in inspection_summary:
            continue
        counts = inspection_summary[split]["class_counts"]
        labels, values = list(counts.keys()), list(counts.values())
        bars = axes[idx].bar(labels, values, color=palette, edgecolor="black", linewidth=0.5)
        axes[idx].set_title(f"{split.capitalize()} — Class Distribution", fontsize=13, fontweight="bold")
        axes[idx].set_ylabel("Number of Images")
        axes[idx].tick_params(axis="x", rotation=35)
        for bar, v in zip(bars, values):
            axes[idx].text(bar.get_x()+bar.get_width()/2, bar.get_height()+8,
                           str(v), ha="center", va="bottom", fontsize=9, fontweight="bold")
    fig.tight_layout()
    fig.savefig(os.path.join(out, "class_distribution.png"), dpi=150)
    plt.show(); plt.close(fig)

    # Pixel intensity distribution
    pixel_values = {c: [] for c in class_names}
    for cls in class_names:
        cls_dir = os.path.join(config["dataset_path"], "train", cls)
        if not os.path.isdir(cls_dir): continue
        files = [f for f in os.listdir(cls_dir) if f.lower().endswith(('.jpg','.jpeg','.png'))]
        chosen = np.random.choice(files, size=min(40, len(files)), replace=False)
        for f in chosen:
            img = np.array(Image.open(os.path.join(cls_dir, f)).convert("RGB"))
            pixel_values[cls].append(img.mean())

    fig, ax = plt.subplots(figsize=(10, 5))
    for i, cls in enumerate(class_names):
        if pixel_values[cls]:
            ax.hist(pixel_values[cls], bins=25, alpha=0.55, label=cls, color=palette[i])
    ax.set_title("Mean Pixel Intensity Distribution (Train)", fontsize=13, fontweight="bold")
    ax.set_xlabel("Mean Pixel Value (0-255)"); ax.set_ylabel("Frequency")
    ax.legend(fontsize=8); fig.tight_layout()
    fig.savefig(os.path.join(out, "pixel_intensity_distribution.png"), dpi=150)
    plt.show(); plt.close(fig)

    # Sample images grid
    fig, axes = plt.subplots(2, config["num_classes"], figsize=(18, 7))
    for col, cls in enumerate(class_names):
        cls_dir = os.path.join(config["dataset_path"], "train", cls)
        if not os.path.isdir(cls_dir): continue
        files = [f for f in os.listdir(cls_dir) if f.lower().endswith(('.jpg','.jpeg','.png'))]
        chosen = np.random.choice(files, size=min(2, len(files)), replace=False)
        for row, f in enumerate(chosen):
            img = Image.open(os.path.join(cls_dir, f)).convert("RGB")
            axes[row, col].imshow(img); axes[row, col].set_title(cls, fontsize=9)
            axes[row, col].axis("off")
    fig.suptitle("Sample Images per Class (Train)", fontsize=14, fontweight="bold", y=1.01)
    fig.tight_layout()
    fig.savefig(os.path.join(out, "sample_images.png"), dpi=150, bbox_inches="tight")
    plt.show(); plt.close(fig)

# %%
#cell 6
# ══════════════════════════════════════════════════════════════
# STAGE 3 — DATA LOADING
# ══════════════════════════════════════════════════════════════

def create_data_generators(config):
    separator("STAGE 3 — DATA LOADING")
    base = config["dataset_path"]

    # No augmentation — dataset is already augmented
    datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1.0/255.0)

    train_gen = datagen.flow_from_directory(
        os.path.join(base, "train"), target_size=config["image_size"],
        batch_size=config["batch_size"], class_mode="categorical",
        classes=config["class_names"], shuffle=True, seed=config["seed"],
    )
    valid_gen = datagen.flow_from_directory(
        os.path.join(base, "valid"), target_size=config["image_size"],
        batch_size=config["batch_size"], class_mode="categorical",
        classes=config["class_names"], shuffle=False, seed=config["seed"],
    )

    print(f"  Train batches/epoch : {len(train_gen)}")
    print(f"  Valid batches/epoch : {len(valid_gen)}")
    print(f"  Class indices       : {train_gen.class_indices}")
    return train_gen, valid_gen

# %%
#cell 7
# ══════════════════════════════════════════════════════════════
# STAGE 4 — MODEL FACTORY (VGG16 & VGG19 ONLY)
# ══════════════════════════════════════════════════════════════

def build_model(model_name, config):
    separator(f"BUILDING MODEL: {model_name}")

    img_size = config["image_size"] + (3,)
    num_classes = config["num_classes"]

    if model_name == "VGG16":
        base_model = tf.keras.applications.VGG16(
            weights="imagenet",
            include_top=False,
            input_shape=img_size
        )

    elif model_name == "VGG19":
        base_model = tf.keras.applications.VGG19(
            weights="imagenet",
            include_top=False,
            input_shape=img_size
        )

    else:
        raise ValueError("Only VGG16 and VGG19 are supported in this version")

    # Freeze base model
    base_model.trainable = False

    # Custom classification head
    x = base_model.output
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dense(512, activation="relu")(x)
    x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(num_classes, activation="softmax")(x)

    model = Model(inputs=base_model.input, outputs=outputs, name=model_name)

    model.summary()
    return model

# %%
#cell 8
# ══════════════════════════════════════════════════════════════
# STAGE 5 — COMPILE & TRAIN
# ══════════════════════════════════════════════════════════════

def compile_and_train(model, train_gen, valid_gen, config):
    separator("STAGE 5 — TRAINING")
    out = config["output_dir"]
    ensure_dir(out)

    optimizer = optimizers.AdamW(
        learning_rate=config["initial_learning_rate"],
        weight_decay=config["weight_decay"],
    )
    loss_fn = keras.losses.CategoricalCrossentropy(
        label_smoothing=config["label_smoothing"],
    )
    model.compile(optimizer=optimizer, loss=loss_fn, metrics=["accuracy"])

    # Class weights
    from sklearn.utils.class_weight import compute_class_weight
    cw = compute_class_weight("balanced", classes=np.arange(config["num_classes"]), y=train_gen.classes)
    class_weight_dict = {i: w for i, w in enumerate(cw)}
    print(f"  Class weights: {class_weight_dict}")

    cb_list = [
        callbacks.EarlyStopping(monitor="val_loss", patience=config["early_stopping_patience"],
                                restore_best_weights=True, verbose=1),
        callbacks.ReduceLROnPlateau(monitor="val_loss", factor=config["reduce_lr_factor"],
                                    patience=config["reduce_lr_patience"],
                                    min_lr=config["min_learning_rate"], verbose=1),
        callbacks.ModelCheckpoint(filepath=os.path.join(out, "best_model.keras"),
                                  monitor="val_loss", save_best_only=True, verbose=1),
        callbacks.CSVLogger(os.path.join(out, "training_log.csv"), separator=",", append=False),
    ]

    print(f"  Optimizer : AdamW (lr={config['initial_learning_rate']}, wd={config['weight_decay']})")
    print(f"  Loss      : CCE (label_smoothing={config['label_smoothing']})")
    print(f"  Epochs    : {config['epochs']} (max), Batch: {config['batch_size']}")

    history = model.fit(
        train_gen, validation_data=valid_gen, epochs=config["epochs"],
        callbacks=cb_list, class_weight=class_weight_dict, verbose=1,
    )
    return history

# %%
#cell 9
# ══════════════════════════════════════════════════════════════
# STAGE 6 — EVALUATION
# ══════════════════════════════════════════════════════════════

def evaluate_model(model, valid_gen, config):
    separator("STAGE 6 — EVALUATION")
    class_names = config["class_names"]

    if len(valid_gen) == 0:
        print("  [WARNING] Validation generator is empty. Cannot perform evaluation.")
        empty_results = {
            "test_loss": -1.0, "test_accuracy": -1.0,
            "classification_report": "No validation data available.",
            "confusion_matrix": [],
            "per_class": {},
        }
        for cls in class_names:
            empty_results["per_class"][cls] = {
                "precision": 0.0, "recall": 0.0,
                "f1_score": 0.0, "support": 0,
            }
        return empty_results

    loss, accuracy = model.evaluate(valid_gen, verbose=0)
    print(f"  Test Loss     : {loss:.4f}")
    print(f"  Test Accuracy : {accuracy:.4f}  ({accuracy*100:.2f}%)")

    valid_gen.reset()
    y_pred_proba = model.predict(valid_gen, verbose=0)
    y_pred = np.argmax(y_pred_proba, axis=1)
    y_true = valid_gen.classes

    # Ensure y_true and y_pred have consistent length
    min_len = min(len(y_true), len(y_pred))
    y_true, y_pred = y_true[:min_len], y_pred[:min_len]

    # Handle cases where min_len might still be 0 if valid_gen had samples but predict yielded nothing or very little
    if min_len == 0:
        print("  [WARNING] No predictions or true labels available for evaluation metrics.")
        empty_results = {
            "test_loss": float(loss), "test_accuracy": float(accuracy),
            "classification_report": "No predictions or true labels available.",
            "confusion_matrix": [],
            "per_class": {},
        }
        for cls in class_names:
            empty_results["per_class"][cls] = {
                "precision": 0.0, "recall": 0.0,
                "f1_score": 0.0, "support": 0,
            }
        return empty_results


    report_str = classification_report(y_true, y_pred, target_names=class_names, digits=4)
    print(f"\n  Classification Report:\n{report_str}")

    cm = confusion_matrix(y_true, y_pred)
    print(f"  Confusion Matrix:\n{cm}")

    precision, recall, f1, support = precision_recall_fscore_support(
        y_true, y_pred, average=None, labels=range(config["num_classes"]))

    results = {
        "test_loss": float(loss), "test_accuracy": float(accuracy),
        "classification_report": report_str, "confusion_matrix": cm.tolist(),
        "per_class": {},
    }
    for i, cls in enumerate(class_names):
        results["per_class"][cls] = {
            "precision": float(precision[i]), "recall": float(recall[i]),
            "f1_score": float(f1[i]), "support": int(support[i]),
        }
    return results

# %%
#cell 10
# ══════════════════════════════════════════════════════════════
# STAGE 7 — VISUALIZATION
# ══════════════════════════════════════════════════════════════

def plot_training_curves(history, config):
    separator("STAGE 7 — VISUALIZATION")
    out = os.path.join(config["output_dir"], "plots")
    ensure_dir(out)
    epochs_ran = range(1, len(history.history["loss"]) + 1)

    # Loss curves
    fig, ax = plt.subplots(figsize=(10, 5))
    ax.plot(epochs_ran, history.history["loss"], label="Train Loss", lw=2, color="#3b82f6")
    ax.plot(epochs_ran, history.history["val_loss"], label="Val Loss", lw=2, color="#ef4444", ls="--")
    ax.set_title("Training & Validation Loss", fontsize=14, fontweight="bold")
    ax.set_xlabel("Epoch"); ax.set_ylabel("Loss"); ax.legend(); ax.grid(alpha=0.3)
    fig.tight_layout(); fig.savefig(os.path.join(out, "loss_curves.png"), dpi=150)
    plt.show(); plt.close(fig)

    # Accuracy curves
    fig, ax = plt.subplots(figsize=(10, 5))
    ax.plot(epochs_ran, history.history["accuracy"], label="Train Acc", lw=2, color="#22c55e")
    ax.plot(epochs_ran, history.history["val_accuracy"], label="Val Acc", lw=2, color="#f97316", ls="--")
    ax.set_title("Training & Validation Accuracy", fontsize=14, fontweight="bold")
    ax.set_xlabel("Epoch"); ax.set_ylabel("Accuracy"); ax.legend(); ax.grid(alpha=0.3)
    fig.tight_layout(); fig.savefig(os.path.join(out, "accuracy_curves.png"), dpi=150)
    plt.show(); plt.close(fig)

    # Combined
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 5))
    ax1.plot(epochs_ran, history.history["loss"], label="Train", lw=2, color="#3b82f6")
    ax1.plot(epochs_ran, history.history["val_loss"], label="Val", lw=2, color="#ef4444", ls="--")
    ax1.set_title("Loss"); ax1.set_xlabel("Epoch"); ax1.set_ylabel("Loss")
    ax1.legend(); ax1.grid(alpha=0.3)
    ax2.plot(epochs_ran, history.history["accuracy"], label="Train", lw=2, color="#22c55e")
    ax2.plot(epochs_ran, history.history["val_accuracy"], label="Val", lw=2, color="#f97316", ls="--")
    ax2.set_title("Accuracy"); ax2.set_xlabel("Epoch"); ax2.set_ylabel("Accuracy")
    ax2.legend(); ax2.grid(alpha=0.3)
    fig.suptitle("VGG Training Summary", fontsize=15, fontweight="bold", y=1.02)
    fig.tight_layout()
    fig.savefig(os.path.join(out, "training_summary.png"), dpi=150, bbox_inches="tight")
    plt.show(); plt.close(fig)


def plot_confusion_matrix(results, config):
    out = os.path.join(config["output_dir"], "plots")
    ensure_dir(out)
    cm = np.array(results["confusion_matrix"])
    class_names = config["class_names"]

    fig, ax = plt.subplots(figsize=(9, 7))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
                xticklabels=class_names, yticklabels=class_names,
                linewidths=0.5, linecolor="gray", ax=ax)
    ax.set_title("Confusion Matrix", fontsize=14, fontweight="bold")
    ax.set_ylabel("True Label"); ax.set_xlabel("Predicted Label")
    plt.xticks(rotation=35, ha="right"); plt.yticks(rotation=0)
    fig.tight_layout(); fig.savefig(os.path.join(out, "confusion_matrix.png"), dpi=150)
    plt.show(); plt.close(fig)

    # Normalized
    cm_norm = cm.astype("float") / cm.sum(axis=1, keepdims=True)
    fig, ax = plt.subplots(figsize=(9, 7))
    sns.heatmap(cm_norm, annot=True, fmt=".2f", cmap="YlOrRd",
                xticklabels=class_names, yticklabels=class_names,
                linewidths=0.5, linecolor="gray", ax=ax, vmin=0, vmax=1)
    ax.set_title("Normalized Confusion Matrix", fontsize=14, fontweight="bold")
    ax.set_ylabel("True Label"); ax.set_xlabel("Predicted Label")
    plt.xticks(rotation=35, ha="right"); plt.yticks(rotation=0)
    fig.tight_layout(); fig.savefig(os.path.join(out, "confusion_matrix_normalized.png"), dpi=150)
    plt.show(); plt.close(fig)

# %%
#cell 11
# ══════════════════════════════════════════════════════════════
# STAGE 8 — SAVE MODEL & RESULTS
# ══════════════════════════════════════════════════════════════

def save_everything(model, history, results, config):
    separator("STAGE 8 — SAVING ARTEFACTS")
    out = config["output_dir"]
    ensure_dir(out)

    # Full model
    model.save(os.path.join(out, "VGG_final.keras"))
    print(f"  ✓ Final model saved")

    # Weights
    model.save_weights(os.path.join(out, "VGG_weights.weights.h5"))
    print(f"  ✓ Weights saved")

    # Architecture JSON
    with open(os.path.join(out, "VGG_architecture.json"), "w") as f:
        json.dump(json.loads(model.to_json()), f, indent=2)
    print(f"  ✓ Architecture JSON saved")

    # Training history
    hist_data = {k: [float(v) for v in vals] for k, vals in history.history.items()}
    with open(os.path.join(out, "training_history.json"), "w") as f:
        json.dump(hist_data, f, indent=2)
    print(f"  ✓ Training history saved")

    # Evaluation results
    with open(os.path.join(out, "evaluation_results.json"), "w") as f:
        json.dump(results, f, indent=2)
    print(f"  ✓ Evaluation results saved")

    # Config snapshot
    config_safe = {k: v for k, v in config.items()}
    config_safe["timestamp"] = datetime.datetime.now().isoformat()
    with open(os.path.join(out, "config_snapshot.json"), "w") as f:
        json.dump(config_safe, f, indent=2)
    print(f"  ✓ Config snapshot saved")

# %%
#cell 12

# ══════════════════════════════════════════════════════════════
# MAIN PIPELINE (SINGLE MODEL TRAINING MODE)
# ══════════════════════════════════════════════════════════════

def main(model_name):
    print("╔══════════════════════════════════════════════════════════════╗")
    print(f"║  TRAINING MODEL: {model_name}")
    print("╚══════════════════════════════════════════════════════════════╝")

    set_seeds(CONFIG["seed"])

    # GPU check
    gpus = tf.config.list_physical_devices("GPU")
    print(f"\nTensorFlow : {tf.__version__}")
    print(f"GPUs       : {len(gpus)}")
    for g in gpus:
        print(f" • {g.name}")

    # Pipeline steps
    inspection = inspect_dataset(CONFIG)
    perform_eda(CONFIG, inspection)
    train_gen, valid_gen = create_data_generators(CONFIG)

    # Build model
    model = build_model(model_name, CONFIG)

    # Train
    history = compile_and_train(model, train_gen, valid_gen, CONFIG)

    # Evaluate
    results = evaluate_model(model, valid_gen, CONFIG)

    # Save
    model.save(f"{CONFIG['output_dir']}/{model_name}.keras")

    # Plots
    plot_training_curves(history, CONFIG)
    plot_confusion_matrix(results, CONFIG)

    print("\n══════════════════════════════")
    print(f"{model_name} Accuracy: {results['test_accuracy']*100:.2f}%")
    print("══════════════════════════════")

# %%
#cell 13 (Run after train all models on next day not run in training models)
# ══════════════════════════════════════════════════════════════
# CELL 13 — LOAD TRAINED VGG MODELS (RUN AFTER TRAINING)
# ══════════════════════════════════════════════════════════════

vgg16 = tf.keras.models.load_model(f"{CONFIG['output_dir']}/VGG16.keras")
vgg19 = tf.keras.models.load_model(f"{CONFIG['output_dir']}/VGG19.keras")

print("✅ VGG16 and VGG19 models loaded successfully")

print("✅ Models loaded successfully")

# %%
# (Run after train all models on next day not run in training models)
#cell 14 (PREDICT SINGLE IMAGE)
import numpy as np
from tensorflow.keras.preprocessing import image

def predict_image(model, img_path):
    img = image.load_img(img_path, target_size=CONFIG["image_size"])
    img_array = image.img_to_array(img) / 255.0
    img_array = np.expand_dims(img_array, axis=0)

    prediction = model.predict(img_array)
    class_idx = np.argmax(prediction)

    return CONFIG["class_names"][class_idx], prediction

# Example usage:
img_path = "/content/sample.jpg"  # change this
label, prob = predict_image(vgg16, img_path)

print("Prediction:", label)

# %%
# ══════════════════════════════════════════════════════════════
# CELL 15 — COMPARE VGG MODELS (RUN AFTER LOADING MODELS)
# ══════════════════════════════════════════════════════════════

models = {
    "VGG16": vgg16,
    "VGG19": vgg19
}

print("\n📊 MODEL COMPARISON RESULTS:\n")

for name, model in models.items():
    loss, acc = model.evaluate(valid_gen, verbose=0)
    print(f"{name} → Accuracy: {acc*100:.2f}% | Loss: {loss:.4f}")

# %%
# cell 16
main("VGG16")
# Out:
# ╔══════════════════════════════════════════════════════════════╗
# ║  TRAINING MODEL: VGG16
# ╚══════════════════════════════════════════════════════════════╝
#
# TensorFlow : 2.19.0
# GPUs       : 1
#  • /physical_device:GPU:0
#
# ════════════════════════════════════════════════════════════════════════
#   STAGE 1 — DATASET INSPECTION
# ════════════════════════════════════════════════════════════════════════
#
#   Split: train
#   Class                      Count         %
#   ------------------------------------------
#   Mild-Demented               1000     20.0%
#   Moderate-Demented           1000     20.0%
#   Non-Demented                1000     20.0%
#   Severe-Demented             1000     20.0%
#   Very-Mild-Demented          1000     20.0%
#   TOTAL                       5000
#
#   Split: valid
#   Class                      Count         %
#   ------------------------------------------
#   Mild-Demented                293     33.7%
#   Moderate-Demented            239     27.5%
#   Non-Demented                 192     22.1%
#   Severe-Demented                4      0.5%
#   Very-Mild-Demented           142     16.3%
#   TOTAL                        870
#
# ════════════════════════════════════════════════════════════════════════
#   STAGE 2 — EDA
# ════════════════════════════════════════════════════════════════════════
# ════════════════════════════════════════════════════════════════════════
#   STAGE 3 — DATA LOADING
# ════════════════════════════════════════════════════════════════════════
# Found 5000 images belonging to 5 classes.
# Found 870 images belonging to 5 classes.
#   Train batches/epoch : 157
#   Valid batches/epoch : 28
#   Class indices       : {'Mild-Demented': 0, 'Moderate-Demented': 1, 'Non-Demented': 2, 'Severe-Demented': 3, 'Very-Mild-Demented': 4}
#
# ════════════════════════════════════════════════════════════════════════
#   BUILDING MODEL: VGG16
# ════════════════════════════════════════════════════════════════════════
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# Model: "VGG16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 224, 224, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 112, 112, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 112, 112, 128)  │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 56, 56, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 28, 28, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 7, 7, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 512)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │       262,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 5)              │         2,565 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,981,957 (57.15 MB)
#  Trainable params: 266,245 (1.02 MB)
#  Non-trainable params: 14,715,712 (56.14 MB)
# ════════════════════════════════════════════════════════════════════════
#   STAGE 5 — TRAINING
# ════════════════════════════════════════════════════════════════════════
#   Class weights: {0: np.float64(1.0), 1: np.float64(1.0), 2: np.float64(1.0), 3: np.float64(1.0), 4: np.float64(1.0)}
#   Optimizer : AdamW (lr=0.001, wd=0.0005)
#   Loss      : CCE (label_smoothing=0.1)
#   Epochs    : 20 (max), Batch: 32
# Epoch 1/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step - accuracy: 0.8048 - loss: 0.8478
# Epoch 1: val_loss improved from None to 1.26234, saving model to /content/drive/MyDrive/OUTPUT/best_model.keras
#
# Epoch 1: finished saving model to /content/drive/MyDrive/OUTPUT/best_model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 594s 4s/step - accuracy: 0.8786 - loss: 0.7036 - val_accuracy: 0.7885 - val_loss: 1.2623 - learning_rate: 0.0010
# Epoch 2/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - accuracy: 0.9372 - loss: 0.5671
# Epoch 2: val_loss improved from 1.26234 to 0.95424, saving model to /content/drive/MyDrive/OUTPUT/best_model.keras
#
# Epoch 2: finished saving model to /content/drive/MyDrive/OUTPUT/best_model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 42s 267ms/step - accuracy: 0.9356 - loss: 0.5711 - val_accuracy: 0.9080 - val_loss: 0.9542 - learning_rate: 0.0010
# Epoch 3/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step - accuracy: 0.9560 - loss: 0.5351
# Epoch 3: val_loss improved from 0.95424 to 0.67589, saving model to /content/drive/MyDrive/OUTPUT/best_model.keras
#
# Epoch 3: finished saving model to /content/drive/MyDrive/OUTPUT/best_model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 43s 274ms/step - accuracy: 0.9542 - loss: 0.5335 - val_accuracy: 0.9299 - val_loss: 0.6759 - learning_rate: 0.0010
# Epoch 4/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - accuracy: 0.9562 - loss: 0.5228
# Epoch 4: val_loss improved from 0.67589 to 0.57670, saving model to /content/drive/MyDrive/OUTPUT/best_model.keras
#
# Epoch 4: finished saving model to /content/drive/MyDrive/OUTPUT/best_model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 42s 270ms/step - accuracy: 0.9590 - loss: 0.5186 - val_accuracy: 0.9126 - val_loss: 0.5767 - learning_rate: 0.0010
# Epoch 5/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - accuracy: 0.9682 - loss: 0.5018
# Epoch 5: val_loss improved from 0.57670 to 0.56234, saving model to /content/drive/MyDrive/OUTPUT/best_model.keras
#
# Epoch 5: finished saving model to /content/drive/MyDrive/OUTPUT/best_model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 42s 265ms/step - accuracy: 0.9652 - loss: 0.5056 - val_accuracy: 0.9207 - val_loss: 0.5623 - learning_rate: 0.0010
# Epoch 6/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - accuracy: 0.9750 - loss: 0.4873
# Epoch 6: val_loss improved from 0.56234 to 0.54846, saving model to /content/drive/MyDrive/OUTPUT/best_model.keras
#
# Epoch 6: finished saving model to /content/drive/MyDrive/OUTPUT/best_model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 85s 285ms/step - accuracy: 0.9708 - loss: 0.4930 - val_accuracy: 0.9207 - val_loss: 0.5485 - learning_rate: 0.0010
# Epoch 7/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - accuracy: 0.9750 - loss: 0.4894
# Epoch 7: val_loss did not improve from 0.54846
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 42s 267ms/step - accuracy: 0.9746 - loss: 0.4894 - val_accuracy: 0.9230 - val_loss: 0.5526 - learning_rate: 0.0010
# Epoch 8/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - accuracy: 0.9802 - loss: 0.4763
# Epoch 8: val_loss improved from 0.54846 to 0.54478, saving model to /content/drive/MyDrive/OUTPUT/best_model.keras
#
# Epoch 8: finished saving model to /content/drive/MyDrive/OUTPUT/best_model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 41s 261ms/step - accuracy: 0.9796 - loss: 0.4786 - val_accuracy: 0.9253 - val_loss: 0.5448 - learning_rate: 0.0010
# Epoch 9/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - accuracy: 0.9809 - loss: 0.4790
# Epoch 9: val_loss did not improve from 0.54478
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 41s 262ms/step - accuracy: 0.9794 - loss: 0.4803 - val_accuracy: 0.9241 - val_loss: 0.5454 - learning_rate: 0.0010
# Epoch 10/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - accuracy: 0.9856 - loss: 0.4659
# Epoch 10: val_loss did not improve from 0.54478
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 41s 256ms/step - accuracy: 0.9850 - loss: 0.4680 - val_accuracy: 0.9276 - val_loss: 0.5673 - learning_rate: 0.0010
# Epoch 11/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step - accuracy: 0.9882 - loss: 0.4633
# Epoch 11: val_loss did not improve from 0.54478
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 41s 260ms/step - accuracy: 0.9884 - loss: 0.4633 - val_accuracy: 0.9218 - val_loss: 0.5494 - learning_rate: 0.0010
# Epoch 12/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - accuracy: 0.9885 - loss: 0.4601
# Epoch 12: val_loss improved from 0.54478 to 0.54377, saving model to /content/drive/MyDrive/OUTPUT/best_model.keras
#
# Epoch 12: finished saving model to /content/drive/MyDrive/OUTPUT/best_model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 41s 259ms/step - accuracy: 0.9876 - loss: 0.4609 - val_accuracy: 0.9322 - val_loss: 0.5438 - learning_rate: 0.0010
# Epoch 13/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - accuracy: 0.9937 - loss: 0.4527
# Epoch 13: val_loss did not improve from 0.54377
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 42s 262ms/step - accuracy: 0.9914 - loss: 0.4554 - val_accuracy: 0.9322 - val_loss: 0.5476 - learning_rate: 0.0010
# Epoch 14/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - accuracy: 0.9903 - loss: 0.4528
# Epoch 14: val_loss did not improve from 0.54377
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 42s 264ms/step - accuracy: 0.9904 - loss: 0.4537 - val_accuracy: 0.9287 - val_loss: 0.5665 - learning_rate: 0.0010
# Epoch 15/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - accuracy: 0.9913 - loss: 0.4529
# Epoch 15: val_loss improved from 0.54377 to 0.54069, saving model to /content/drive/MyDrive/OUTPUT/best_model.keras
#
# Epoch 15: finished saving model to /content/drive/MyDrive/OUTPUT/best_model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 46s 292ms/step - accuracy: 0.9888 - loss: 0.4569 - val_accuracy: 0.9322 - val_loss: 0.5407 - learning_rate: 0.0010
# Epoch 16/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - accuracy: 0.9960 - loss: 0.4482
# Epoch 16: val_loss did not improve from 0.54069
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 42s 264ms/step - accuracy: 0.9950 - loss: 0.4494 - val_accuracy: 0.9276 - val_loss: 0.5557 - learning_rate: 0.0010
# Epoch 17/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - accuracy: 0.9933 - loss: 0.4478
# Epoch 17: val_loss did not improve from 0.54069
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 43s 273ms/step - accuracy: 0.9934 - loss: 0.4488 - val_accuracy: 0.9207 - val_loss: 0.5598 - learning_rate: 0.0010
# Epoch 18/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step - accuracy: 0.9958 - loss: 0.4455
# Epoch 18: val_loss did not improve from 0.54069
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 44s 281ms/step - accuracy: 0.9954 - loss: 0.4450 - val_accuracy: 0.9276 - val_loss: 0.5550 - learning_rate: 0.0010
# Epoch 19/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.9960 - loss: 0.4408
# Epoch 19: val_loss did not improve from 0.54069
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 45s 287ms/step - accuracy: 0.9950 - loss: 0.4435 - val_accuracy: 0.9276 - val_loss: 0.5451 - learning_rate: 0.0010
# Epoch 20/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 0.9955 - loss: 0.4441
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 20: val_loss did not improve from 0.54069
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 45s 284ms/step - accuracy: 0.9952 - loss: 0.4443 - val_accuracy: 0.9368 - val_loss: 0.5441 - learning_rate: 0.0010
# Restoring model weights from the end of the best epoch: 15.
#
# ════════════════════════════════════════════════════════════════════════
#   STAGE 6 — EVALUATION
# ════════════════════════════════════════════════════════════════════════
#   Test Loss     : 0.5407
#   Test Accuracy : 0.9322  (93.22%)
#
#   Classification Report:
#                     precision    recall  f1-score   support
#
#      Mild-Demented     0.9403    0.8601    0.8984       293
#  Moderate-Demented     0.9628    0.9749    0.9688       239
#       Non-Demented     0.8426    0.9479    0.8922       192
#    Severe-Demented     1.0000    0.5000    0.6667         4
# Very-Mild-Demented     1.0000    1.0000    1.0000       142
#
#           accuracy                         0.9322       870
#          macro avg     0.9491    0.8566    0.8852       870
#       weighted avg     0.9349    0.9322    0.9319       870
#
#   Confusion Matrix:
# [[252   7  34   0   0]
#  [  6 233   0   0   0]
#  [ 10   0 182   0   0]
#  [  0   2   0   2   0]
#  [  0   0   0   0 142]]
#
# ════════════════════════════════════════════════════════════════════════
#   STAGE 7 — VISUALIZATION
# ════════════════════════════════════════════════════════════════════════
# ══════════════════════════════
# VGG16 Accuracy: 93.22%
# ══════════════════════════════

# %%
# cell 16
main("VGG19")
# Out:
# ╔══════════════════════════════════════════════════════════════╗
# ║  TRAINING MODEL: VGG19
# ╚══════════════════════════════════════════════════════════════╝
#
# TensorFlow : 2.19.0
# GPUs       : 1
#  • /physical_device:GPU:0
#
# ════════════════════════════════════════════════════════════════════════
#   STAGE 1 — DATASET INSPECTION
# ════════════════════════════════════════════════════════════════════════
#
#   Split: train
#   Class                      Count         %
#   ------------------------------------------
#   Mild-Demented               1000     20.0%
#   Moderate-Demented           1000     20.0%
#   Non-Demented                1000     20.0%
#   Severe-Demented             1000     20.0%
#   Very-Mild-Demented          1000     20.0%
#   TOTAL                       5000
#
#   Split: valid
#   Class                      Count         %
#   ------------------------------------------
#   Mild-Demented                293     33.7%
#   Moderate-Demented            239     27.5%
#   Non-Demented                 192     22.1%
#   Severe-Demented                4      0.5%
#   Very-Mild-Demented           142     16.3%
#   TOTAL                        870
#
# ════════════════════════════════════════════════════════════════════════
#   STAGE 2 — EDA
# ════════════════════════════════════════════════════════════════════════
# ════════════════════════════════════════════════════════════════════════
#   STAGE 3 — DATA LOADING
# ════════════════════════════════════════════════════════════════════════
# Found 5000 images belonging to 5 classes.
# Found 870 images belonging to 5 classes.
#   Train batches/epoch : 157
#   Valid batches/epoch : 28
#   Class indices       : {'Mild-Demented': 0, 'Moderate-Demented': 1, 'Non-Demented': 2, 'Severe-Demented': 3, 'Very-Mild-Demented': 4}
#
# ════════════════════════════════════════════════════════════════════════
#   BUILDING MODEL: VGG19
# ════════════════════════════════════════════════════════════════════════
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "VGG19"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 224, 224, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 112, 112, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 112, 112, 128)  │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 56, 56, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv4 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 28, 28, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv4 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv4 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 7, 7, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 512)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │       262,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 5)              │         2,565 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 20,291,653 (77.41 MB)
#  Trainable params: 266,245 (1.02 MB)
#  Non-trainable params: 20,025,408 (76.39 MB)
# ════════════════════════════════════════════════════════════════════════
#   STAGE 5 — TRAINING
# ════════════════════════════════════════════════════════════════════════
#   Class weights: {0: np.float64(1.0), 1: np.float64(1.0), 2: np.float64(1.0), 3: np.float64(1.0), 4: np.float64(1.0)}
#   Optimizer : AdamW (lr=0.001, wd=0.0005)
#   Loss      : CCE (label_smoothing=0.1)
#   Epochs    : 20 (max), Batch: 32
# Epoch 1/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step - accuracy: 0.7940 - loss: 0.8411
# Epoch 1: val_loss improved from None to 1.28195, saving model to /content/drive/MyDrive/OUTPUT/best_model.keras
#
# Epoch 1: finished saving model to /content/drive/MyDrive/OUTPUT/best_model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 441s 3s/step - accuracy: 0.8674 - loss: 0.7065 - val_accuracy: 0.4747 - val_loss: 1.2819 - learning_rate: 0.0010
# Epoch 2/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - accuracy: 0.9250 - loss: 0.5927
# Epoch 2: val_loss improved from 1.28195 to 0.91670, saving model to /content/drive/MyDrive/OUTPUT/best_model.keras
#
# Epoch 2: finished saving model to /content/drive/MyDrive/OUTPUT/best_model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 48s 307ms/step - accuracy: 0.9276 - loss: 0.5829 - val_accuracy: 0.8644 - val_loss: 0.9167 - learning_rate: 0.0010
# Epoch 3/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step - accuracy: 0.9364 - loss: 0.5580
# Epoch 3: val_loss improved from 0.91670 to 0.69776, saving model to /content/drive/MyDrive/OUTPUT/best_model.keras
#
# Epoch 3: finished saving model to /content/drive/MyDrive/OUTPUT/best_model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 47s 299ms/step - accuracy: 0.9412 - loss: 0.5509 - val_accuracy: 0.9207 - val_loss: 0.6978 - learning_rate: 0.0010
# Epoch 4/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step - accuracy: 0.9529 - loss: 0.5282
# Epoch 4: val_loss improved from 0.69776 to 0.56484, saving model to /content/drive/MyDrive/OUTPUT/best_model.keras
#
# Epoch 4: finished saving model to /content/drive/MyDrive/OUTPUT/best_model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 82s 302ms/step - accuracy: 0.9526 - loss: 0.5281 - val_accuracy: 0.9207 - val_loss: 0.5648 - learning_rate: 0.0010
# Epoch 5/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step - accuracy: 0.9666 - loss: 0.5144
# Epoch 5: val_loss improved from 0.56484 to 0.56447, saving model to /content/drive/MyDrive/OUTPUT/best_model.keras
#
# Epoch 5: finished saving model to /content/drive/MyDrive/OUTPUT/best_model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 45s 285ms/step - accuracy: 0.9610 - loss: 0.5171 - val_accuracy: 0.9138 - val_loss: 0.5645 - learning_rate: 0.0010
# Epoch 6/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.9646 - loss: 0.5028
# Epoch 6: val_loss improved from 0.56447 to 0.56342, saving model to /content/drive/MyDrive/OUTPUT/best_model.keras
#
# Epoch 6: finished saving model to /content/drive/MyDrive/OUTPUT/best_model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 47s 300ms/step - accuracy: 0.9618 - loss: 0.5070 - val_accuracy: 0.9172 - val_loss: 0.5634 - learning_rate: 0.0010
# Epoch 7/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.9715 - loss: 0.4980
# Epoch 7: val_loss did not improve from 0.56342
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 46s 290ms/step - accuracy: 0.9678 - loss: 0.5029 - val_accuracy: 0.9195 - val_loss: 0.5737 - learning_rate: 0.0010
# Epoch 8/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - accuracy: 0.9785 - loss: 0.4817
# Epoch 8: val_loss improved from 0.56342 to 0.55244, saving model to /content/drive/MyDrive/OUTPUT/best_model.keras
#
# Epoch 8: finished saving model to /content/drive/MyDrive/OUTPUT/best_model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 46s 291ms/step - accuracy: 0.9756 - loss: 0.4859 - val_accuracy: 0.9299 - val_loss: 0.5524 - learning_rate: 0.0010
# Epoch 9/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step - accuracy: 0.9770 - loss: 0.4871
# Epoch 9: val_loss did not improve from 0.55244
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 83s 300ms/step - accuracy: 0.9804 - loss: 0.4822 - val_accuracy: 0.9195 - val_loss: 0.5581 - learning_rate: 0.0010
# Epoch 10/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 0.9832 - loss: 0.4776
# Epoch 10: val_loss improved from 0.55244 to 0.54982, saving model to /content/drive/MyDrive/OUTPUT/best_model.keras
#
# Epoch 10: finished saving model to /content/drive/MyDrive/OUTPUT/best_model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 82s 301ms/step - accuracy: 0.9794 - loss: 0.4790 - val_accuracy: 0.9264 - val_loss: 0.5498 - learning_rate: 0.0010
# Epoch 11/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step - accuracy: 0.9871 - loss: 0.4736
# Epoch 11: val_loss did not improve from 0.54982
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 45s 282ms/step - accuracy: 0.9832 - loss: 0.4777 - val_accuracy: 0.9184 - val_loss: 0.5779 - learning_rate: 0.0010
# Epoch 12/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step - accuracy: 0.9787 - loss: 0.4746
# Epoch 12: val_loss did not improve from 0.54982
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 46s 293ms/step - accuracy: 0.9804 - loss: 0.4761 - val_accuracy: 0.9218 - val_loss: 0.5656 - learning_rate: 0.0010
# Epoch 13/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 0.9861 - loss: 0.4680
# Epoch 13: val_loss did not improve from 0.54982
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 45s 287ms/step - accuracy: 0.9838 - loss: 0.4721 - val_accuracy: 0.9184 - val_loss: 0.5688 - learning_rate: 0.0010
# Epoch 14/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - accuracy: 0.9880 - loss: 0.4621
# Epoch 14: val_loss improved from 0.54982 to 0.54308, saving model to /content/drive/MyDrive/OUTPUT/best_model.keras
#
# Epoch 14: finished saving model to /content/drive/MyDrive/OUTPUT/best_model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 46s 290ms/step - accuracy: 0.9872 - loss: 0.4646 - val_accuracy: 0.9253 - val_loss: 0.5431 - learning_rate: 0.0010
# Epoch 15/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - accuracy: 0.9857 - loss: 0.4616
# Epoch 15: val_loss did not improve from 0.54308
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 46s 291ms/step - accuracy: 0.9860 - loss: 0.4632 - val_accuracy: 0.9264 - val_loss: 0.5575 - learning_rate: 0.0010
# Epoch 16/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.9911 - loss: 0.4590
# Epoch 16: val_loss did not improve from 0.54308
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 49s 314ms/step - accuracy: 0.9884 - loss: 0.4608 - val_accuracy: 0.9356 - val_loss: 0.5463 - learning_rate: 0.0010
# Epoch 17/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step - accuracy: 0.9893 - loss: 0.4574
# Epoch 17: val_loss did not improve from 0.54308
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 84s 324ms/step - accuracy: 0.9894 - loss: 0.4576 - val_accuracy: 0.9161 - val_loss: 0.5707 - learning_rate: 0.0010
# Epoch 18/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - accuracy: 0.9866 - loss: 0.4578
# Epoch 18: val_loss did not improve from 0.54308
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 45s 284ms/step - accuracy: 0.9886 - loss: 0.4553 - val_accuracy: 0.9322 - val_loss: 0.5487 - learning_rate: 0.0010
# Epoch 19/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step - accuracy: 0.9920 - loss: 0.4509
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 19: val_loss did not improve from 0.54308
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 46s 293ms/step - accuracy: 0.9902 - loss: 0.4531 - val_accuracy: 0.9333 - val_loss: 0.5466 - learning_rate: 0.0010
# Epoch 20/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - accuracy: 0.9932 - loss: 0.4485
# Epoch 20: val_loss did not improve from 0.54308
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 45s 289ms/step - accuracy: 0.9944 - loss: 0.4458 - val_accuracy: 0.9322 - val_loss: 0.5478 - learning_rate: 5.0000e-04
# Restoring model weights from the end of the best epoch: 14.
#
# ════════════════════════════════════════════════════════════════════════
#   STAGE 6 — EVALUATION
# ════════════════════════════════════════════════════════════════════════
#   Test Loss     : 0.5431
#   Test Accuracy : 0.9253  (92.53%)
#
#   Classification Report:
#                     precision    recall  f1-score   support
#
#      Mild-Demented     0.8962    0.8840    0.8900       293
#  Moderate-Demented     0.9627    0.9707    0.9667       239
#       Non-Demented     0.8705    0.8750    0.8727       192
#    Severe-Demented     1.0000    1.0000    1.0000         4
# Very-Mild-Demented     0.9930    1.0000    0.9965       142
#
#           accuracy                         0.9253       870
#          macro avg     0.9445    0.9459    0.9452       870
#       weighted avg     0.9251    0.9253    0.9251       870
#
#   Confusion Matrix:
# [[259   9  25   0   0]
#  [  7 232   0   0   0]
#  [ 23   0 168   0   1]
#  [  0   0   0   4   0]
#  [  0   0   0   0 142]]
#
# ════════════════════════════════════════════════════════════════════════
#   STAGE 7 — VISUALIZATION
# ════════════════════════════════════════════════════════════════════════
# ══════════════════════════════
# VGG19 Accuracy: 92.53%
# ══════════════════════════════
