# %%
import os, json, datetime, warnings
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
from PIL import Image

os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, callbacks, optimizers, regularizers, Model
from sklearn.metrics import (
    classification_report, confusion_matrix, precision_recall_fscore_support,
)

warnings.filterwarnings("ignore")

# %%
# ── Mount Google Drive ──
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# ══════════════════════════════════════════════════════════════
# CONFIGURATION
# ══════════════════════════════════════════════════════════════
CONFIG = {
    "dataset_path": "/content/drive/MyDrive/DATASET",
    "output_dir": "/content/drive/MyDrive/OUTPUT",
    "image_size": (224, 224),
    "num_channels": 3,
    "num_classes": 5,
    "class_names": [
        "Mild-Demented", "Moderate-Demented", "Non-Demented",
        "Severe-Demented", "Very-Mild-Demented",
    ],
    "batch_size": 32,
    "epochs": 100,
    "initial_learning_rate": 1e-3,
    "min_learning_rate": 1e-7,
    "weight_decay": 5e-4,
    "dropout_fc1": 0.5,
    "dropout_fc2": 0.5,
    "label_smoothing": 0.1,
    "early_stopping_patience": 12,
    "reduce_lr_patience": 5,
    "reduce_lr_factor": 0.5,
    "seed": 42,
}

# ══════════════════════════════════════════════════════════════
# UTILITIES
# ══════════════════════════════════════════════════════════════

def set_seeds(seed):
    np.random.seed(seed)
    tf.random.set_seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)

def ensure_dir(path):
    os.makedirs(path, exist_ok=True)

def separator(title):
    print(f"\n{'═'*72}\n  {title}\n{'═'*72}")

# %%
# ══════════════════════════════════════════════════════════════
# STAGE 1 — DATASET INSPECTION
# ══════════════════════════════════════════════════════════════

def inspect_dataset(config):
    separator("STAGE 1 — DATASET INSPECTION")
    base = config["dataset_path"]
    class_names = config["class_names"]
    summary = {}

    for split in ["train", "valid"]:
        split_path = os.path.join(base, split)
        if not os.path.isdir(split_path):
            print(f"  [WARNING] Missing: {split_path}")
            continue

        print(f"\n  Split: {split}")
        print(f"  {'Class':<25} {'Count':>6}  {'%':>8}")
        print(f"  {'-'*42}")

        class_counts = {}
        total = 0
        for cls in class_names:
            cls_path = os.path.join(split_path, cls)
            if not os.path.isdir(cls_path):
                class_counts[cls] = 0
                continue
            files = [f for f in os.listdir(cls_path)
                     if f.lower().endswith(('.jpg','.jpeg','.png'))]
            class_counts[cls] = len(files)
            total += len(files)

        for cls in class_names:
            cnt = class_counts.get(cls, 0)
            pct = (cnt / total * 100) if total > 0 else 0
            print(f"  {cls:<25} {cnt:>6}  {pct:>7.1f}%")
        print(f"  {'TOTAL':<25} {total:>6}")

        summary[split] = {"class_counts": class_counts, "total": total}

    return summary

# %%
# ══════════════════════════════════════════════════════════════
# STAGE 2 — EXPLORATORY DATA ANALYSIS
# ══════════════════════════════════════════════════════════════

def perform_eda(config, inspection_summary):
    separator("STAGE 2 — EDA")
    out = os.path.join(config["output_dir"], "eda")
    ensure_dir(out)
    class_names = config["class_names"]
    palette = sns.color_palette("viridis", n_colors=config["num_classes"])

    # Class distribution
    fig, axes = plt.subplots(1, 2, figsize=(14, 5))
    for idx, split in enumerate(["train", "valid"]):
        if split not in inspection_summary:
            continue
        counts = inspection_summary[split]["class_counts"]
        labels, values = list(counts.keys()), list(counts.values())
        bars = axes[idx].bar(labels, values, color=palette, edgecolor="black", linewidth=0.5)
        axes[idx].set_title(f"{split.capitalize()} — Class Distribution", fontsize=13, fontweight="bold")
        axes[idx].set_ylabel("Number of Images")
        axes[idx].tick_params(axis="x", rotation=35)
        for bar, v in zip(bars, values):
            axes[idx].text(bar.get_x()+bar.get_width()/2, bar.get_height()+8,
                           str(v), ha="center", va="bottom", fontsize=9, fontweight="bold")
    fig.tight_layout()
    fig.savefig(os.path.join(out, "class_distribution.png"), dpi=150)
    plt.show(); plt.close(fig)

    # Pixel intensity distribution
    pixel_values = {c: [] for c in class_names}
    for cls in class_names:
        cls_dir = os.path.join(config["dataset_path"], "train", cls)
        if not os.path.isdir(cls_dir): continue
        files = [f for f in os.listdir(cls_dir) if f.lower().endswith(('.jpg','.jpeg','.png'))]
        chosen = np.random.choice(files, size=min(40, len(files)), replace=False)
        for f in chosen:
            img = np.array(Image.open(os.path.join(cls_dir, f)).convert("RGB"))
            pixel_values[cls].append(img.mean())

    fig, ax = plt.subplots(figsize=(10, 5))
    for i, cls in enumerate(class_names):
        if pixel_values[cls]:
            ax.hist(pixel_values[cls], bins=25, alpha=0.55, label=cls, color=palette[i])
    ax.set_title("Mean Pixel Intensity Distribution (Train)", fontsize=13, fontweight="bold")
    ax.set_xlabel("Mean Pixel Value (0-255)"); ax.set_ylabel("Frequency")
    ax.legend(fontsize=8); fig.tight_layout()
    fig.savefig(os.path.join(out, "pixel_intensity_distribution.png"), dpi=150)
    plt.show(); plt.close(fig)

    # Sample images grid
    fig, axes = plt.subplots(2, config["num_classes"], figsize=(18, 7))
    for col, cls in enumerate(class_names):
        cls_dir = os.path.join(config["dataset_path"], "train", cls)
        if not os.path.isdir(cls_dir): continue
        files = [f for f in os.listdir(cls_dir) if f.lower().endswith(('.jpg','.jpeg','.png'))]
        chosen = np.random.choice(files, size=min(2, len(files)), replace=False)
        for row, f in enumerate(chosen):
            img = Image.open(os.path.join(cls_dir, f)).convert("RGB")
            axes[row, col].imshow(img); axes[row, col].set_title(cls, fontsize=9)
            axes[row, col].axis("off")
    fig.suptitle("Sample Images per Class (Train)", fontsize=14, fontweight="bold", y=1.01)
    fig.tight_layout()
    fig.savefig(os.path.join(out, "sample_images.png"), dpi=150, bbox_inches="tight")
    plt.show(); plt.close(fig)

# %%
# ══════════════════════════════════════════════════════════════
# STAGE 3 — DATA LOADING
# ══════════════════════════════════════════════════════════════

def create_data_generators(config):
    separator("STAGE 3 — DATA LOADING")
    base = config["dataset_path"]

    # No augmentation — dataset is already augmented
    datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1.0/255.0)

    train_gen = datagen.flow_from_directory(
        os.path.join(base, "train"), target_size=config["image_size"],
        batch_size=config["batch_size"], class_mode="categorical",
        classes=config["class_names"], shuffle=True, seed=config["seed"],
    )
    valid_gen = datagen.flow_from_directory(
        os.path.join(base, "valid"), target_size=config["image_size"],
        batch_size=config["batch_size"], class_mode="categorical",
        classes=config["class_names"], shuffle=False, seed=config["seed"],
    )

    print(f"  Train batches/epoch : {len(train_gen)}")
    print(f"  Valid batches/epoch : {len(valid_gen)}")
    print(f"  Class indices       : {train_gen.class_indices}")
    return train_gen, valid_gen

# %%
# ══════════════════════════════════════════════════════════════
# STAGE 4 — VGG-16 ARCHITECTURE
# ══════════════════════════════════════════════════════════════

def build_vgg16(config):
    separator("STAGE 4 — VGG-16 ARCHITECTURE")
    img_h, img_w = config["image_size"]      # 224, 224
    wd = config["weight_decay"]               # 5e-4
    l2 = regularizers.l2(wd)

    inputs = layers.Input(shape=(img_h, img_w, 3), name="input_image")

    # ── Block 1 ── 2× Conv(64) ──────────────────────────────
    # Input: 224×224×3  →  Output: 112×112×64
    x = layers.Conv2D(64, (3,3), padding="same", kernel_regularizer=l2, name="block1_conv1")(inputs)
    x = layers.BatchNormalization(name="block1_bn1")(x)
    x = layers.Activation("relu", name="block1_relu1")(x)

    x = layers.Conv2D(64, (3,3), padding="same", kernel_regularizer=l2, name="block1_conv2")(x)
    x = layers.BatchNormalization(name="block1_bn2")(x)
    x = layers.Activation("relu", name="block1_relu2")(x)

    x = layers.MaxPooling2D((2,2), strides=2, name="block1_pool")(x)

    # ── Block 2 ── 2× Conv(128) ─────────────────────────────
    # Input: 112×112×64  →  Output: 56×56×128
    x = layers.Conv2D(128, (3,3), padding="same", kernel_regularizer=l2, name="block2_conv1")(x)
    x = layers.BatchNormalization(name="block2_bn1")(x)
    x = layers.Activation("relu", name="block2_relu1")(x)

    x = layers.Conv2D(128, (3,3), padding="same", kernel_regularizer=l2, name="block2_conv2")(x)
    x = layers.BatchNormalization(name="block2_bn2")(x)
    x = layers.Activation("relu", name="block2_relu2")(x)

    x = layers.MaxPooling2D((2,2), strides=2, name="block2_pool")(x)

    # ── Block 3 ── 3× Conv(256) ─────────────────────────────
    # Input: 56×56×128  →  Output: 28×28×256
    x = layers.Conv2D(256, (3,3), padding="same", kernel_regularizer=l2, name="block3_conv1")(x)
    x = layers.BatchNormalization(name="block3_bn1")(x)
    x = layers.Activation("relu", name="block3_relu1")(x)

    x = layers.Conv2D(256, (3,3), padding="same", kernel_regularizer=l2, name="block3_conv2")(x)
    x = layers.BatchNormalization(name="block3_bn2")(x)
    x = layers.Activation("relu", name="block3_relu2")(x)

    x = layers.Conv2D(256, (3,3), padding="same", kernel_regularizer=l2, name="block3_conv3")(x)
    x = layers.BatchNormalization(name="block3_bn3")(x)
    x = layers.Activation("relu", name="block3_relu3")(x)

    x = layers.MaxPooling2D((2,2), strides=2, name="block3_pool")(x)

    # ── Block 4 ── 3× Conv(512) ─────────────────────────────
    # Input: 28×28×256  →  Output: 14×14×512
    x = layers.Conv2D(512, (3,3), padding="same", kernel_regularizer=l2, name="block4_conv1")(x)
    x = layers.BatchNormalization(name="block4_bn1")(x)
    x = layers.Activation("relu", name="block4_relu1")(x)

    x = layers.Conv2D(512, (3,3), padding="same", kernel_regularizer=l2, name="block4_conv2")(x)
    x = layers.BatchNormalization(name="block4_bn2")(x)
    x = layers.Activation("relu", name="block4_relu2")(x)

    x = layers.Conv2D(512, (3,3), padding="same", kernel_regularizer=l2, name="block4_conv3")(x)
    x = layers.BatchNormalization(name="block4_bn3")(x)
    x = layers.Activation("relu", name="block4_relu3")(x)

    x = layers.MaxPooling2D((2,2), strides=2, name="block4_pool")(x)

    # ── Block 5 ── 3× Conv(512) ─────────────────────────────
    # Input: 14×14×512  →  Output: 7×7×512
    x = layers.Conv2D(512, (3,3), padding="same", kernel_regularizer=l2, name="block5_conv1")(x)
    x = layers.BatchNormalization(name="block5_bn1")(x)
    x = layers.Activation("relu", name="block5_relu1")(x)

    x = layers.Conv2D(512, (3,3), padding="same", kernel_regularizer=l2, name="block5_conv2")(x)
    x = layers.BatchNormalization(name="block5_bn2")(x)
    x = layers.Activation("relu", name="block5_relu2")(x)

    x = layers.Conv2D(512, (3,3), padding="same", kernel_regularizer=l2, name="block5_conv3")(x)
    x = layers.BatchNormalization(name="block5_bn3")(x)
    x = layers.Activation("relu", name="block5_relu3")(x)

    x = layers.MaxPooling2D((2,2), strides=2, name="block5_pool")(x)
    # Output: 7×7×512

    # ── FC Layers ────────────────────────────────────────────
    # Flatten: 7×7×512 = 25,088 values
    x = layers.Flatten(name="flatten")(x)

    x = layers.Dense(4096, kernel_regularizer=l2, name="fc1")(x)
    x = layers.BatchNormalization(name="bn_fc1")(x)
    x = layers.Activation("relu", name="relu_fc1")(x)
    x = layers.Dropout(config["dropout_fc1"], name="drop1")(x)

    x = layers.Dense(4096, kernel_regularizer=l2, name="fc2")(x)
    x = layers.BatchNormalization(name="bn_fc2")(x)
    x = layers.Activation("relu", name="relu_fc2")(x)
    x = layers.Dropout(config["dropout_fc2"], name="drop2")(x)

    outputs = layers.Dense(config["num_classes"], activation="softmax", name="predictions")(x)

    model = Model(inputs=inputs, outputs=outputs, name="VGG16")
    model.summary()
    return model

# %%
# ══════════════════════════════════════════════════════════════
# STAGE 5 — COMPILE & TRAIN
# ══════════════════════════════════════════════════════════════

def compile_and_train(model, train_gen, valid_gen, config):
    separator("STAGE 5 — TRAINING")
    out = config["output_dir"]
    ensure_dir(out)

    optimizer = optimizers.AdamW(
        learning_rate=config["initial_learning_rate"],
        weight_decay=config["weight_decay"],
    )
    loss_fn = keras.losses.CategoricalCrossentropy(
        label_smoothing=config["label_smoothing"],
    )
    model.compile(optimizer=optimizer, loss=loss_fn, metrics=["accuracy"])

    # Class weights
    from sklearn.utils.class_weight import compute_class_weight
    cw = compute_class_weight("balanced", classes=np.arange(config["num_classes"]), y=train_gen.classes)
    class_weight_dict = {i: w for i, w in enumerate(cw)}
    print(f"  Class weights: {class_weight_dict}")

    cb_list = [
        callbacks.EarlyStopping(monitor="val_loss", patience=config["early_stopping_patience"],
                                restore_best_weights=True, verbose=1),
        callbacks.ReduceLROnPlateau(monitor="val_loss", factor=config["reduce_lr_factor"],
                                    patience=config["reduce_lr_patience"],
                                    min_lr=config["min_learning_rate"], verbose=1),
        callbacks.ModelCheckpoint(filepath=os.path.join(out, "best_model.keras"),
                                  monitor="val_loss", save_best_only=True, verbose=1),
        callbacks.CSVLogger(os.path.join(out, "training_log.csv"), separator=",", append=False),
    ]

    print(f"  Optimizer : AdamW (lr={config['initial_learning_rate']}, wd={config['weight_decay']})")
    print(f"  Loss      : CCE (label_smoothing={config['label_smoothing']})")
    print(f"  Epochs    : {config['epochs']} (max), Batch: {config['batch_size']}")

    history = model.fit(
        train_gen, validation_data=valid_gen, epochs=config["epochs"],
        callbacks=cb_list, class_weight=class_weight_dict, verbose=1,
    )
    return history

# %%
# ══════════════════════════════════════════════════════════════
# STAGE 6 — EVALUATION
# ══════════════════════════════════════════════════════════════

def evaluate_model(model, valid_gen, config):
    separator("STAGE 6 — EVALUATION")
    class_names = config["class_names"]

    if len(valid_gen) == 0:
        print("  [WARNING] Validation generator is empty. Cannot perform evaluation.")
        empty_results = {
            "test_loss": -1.0, "test_accuracy": -1.0,
            "classification_report": "No validation data available.",
            "confusion_matrix": [],
            "per_class": {},
        }
        for cls in class_names:
            empty_results["per_class"][cls] = {
                "precision": 0.0, "recall": 0.0,
                "f1_score": 0.0, "support": 0,
            }
        return empty_results

    loss, accuracy = model.evaluate(valid_gen, verbose=0)
    print(f"  Test Loss     : {loss:.4f}")
    print(f"  Test Accuracy : {accuracy:.4f}  ({accuracy*100:.2f}%)")

    valid_gen.reset()
    y_pred_proba = model.predict(valid_gen, verbose=0)
    y_pred = np.argmax(y_pred_proba, axis=1)
    y_true = valid_gen.classes

    # Ensure y_true and y_pred have consistent length
    min_len = min(len(y_true), len(y_pred))
    y_true, y_pred = y_true[:min_len], y_pred[:min_len]

    # Handle cases where min_len might still be 0 if valid_gen had samples but predict yielded nothing or very little
    if min_len == 0:
        print("  [WARNING] No predictions or true labels available for evaluation metrics.")
        empty_results = {
            "test_loss": float(loss), "test_accuracy": float(accuracy),
            "classification_report": "No predictions or true labels available.",
            "confusion_matrix": [],
            "per_class": {},
        }
        for cls in class_names:
            empty_results["per_class"][cls] = {
                "precision": 0.0, "recall": 0.0,
                "f1_score": 0.0, "support": 0,
            }
        return empty_results


    report_str = classification_report(y_true, y_pred, target_names=class_names, digits=4)
    print(f"\n  Classification Report:\n{report_str}")

    cm = confusion_matrix(y_true, y_pred)
    print(f"  Confusion Matrix:\n{cm}")

    precision, recall, f1, support = precision_recall_fscore_support(
        y_true, y_pred, average=None, labels=range(config["num_classes"]))

    results = {
        "test_loss": float(loss), "test_accuracy": float(accuracy),
        "classification_report": report_str, "confusion_matrix": cm.tolist(),
        "per_class": {},
    }
    for i, cls in enumerate(class_names):
        results["per_class"][cls] = {
            "precision": float(precision[i]), "recall": float(recall[i]),
            "f1_score": float(f1[i]), "support": int(support[i]),
        }
    return results

# %%
# ══════════════════════════════════════════════════════════════
# STAGE 7 — VISUALIZATION
# ══════════════════════════════════════════════════════════════

def plot_training_curves(history, config):
    separator("STAGE 7 — VISUALIZATION")
    out = os.path.join(config["output_dir"], "plots")
    ensure_dir(out)
    epochs_ran = range(1, len(history.history["loss"]) + 1)

    # Loss curves
    fig, ax = plt.subplots(figsize=(10, 5))
    ax.plot(epochs_ran, history.history["loss"], label="Train Loss", lw=2, color="#3b82f6")
    ax.plot(epochs_ran, history.history["val_loss"], label="Val Loss", lw=2, color="#ef4444", ls="--")
    ax.set_title("Training & Validation Loss", fontsize=14, fontweight="bold")
    ax.set_xlabel("Epoch"); ax.set_ylabel("Loss"); ax.legend(); ax.grid(alpha=0.3)
    fig.tight_layout(); fig.savefig(os.path.join(out, "loss_curves.png"), dpi=150)
    plt.show(); plt.close(fig)

    # Accuracy curves
    fig, ax = plt.subplots(figsize=(10, 5))
    ax.plot(epochs_ran, history.history["accuracy"], label="Train Acc", lw=2, color="#22c55e")
    ax.plot(epochs_ran, history.history["val_accuracy"], label="Val Acc", lw=2, color="#f97316", ls="--")
    ax.set_title("Training & Validation Accuracy", fontsize=14, fontweight="bold")
    ax.set_xlabel("Epoch"); ax.set_ylabel("Accuracy"); ax.legend(); ax.grid(alpha=0.3)
    fig.tight_layout(); fig.savefig(os.path.join(out, "accuracy_curves.png"), dpi=150)
    plt.show(); plt.close(fig)

    # Combined
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 5))
    ax1.plot(epochs_ran, history.history["loss"], label="Train", lw=2, color="#3b82f6")
    ax1.plot(epochs_ran, history.history["val_loss"], label="Val", lw=2, color="#ef4444", ls="--")
    ax1.set_title("Loss"); ax1.set_xlabel("Epoch"); ax1.set_ylabel("Loss")
    ax1.legend(); ax1.grid(alpha=0.3)
    ax2.plot(epochs_ran, history.history["accuracy"], label="Train", lw=2, color="#22c55e")
    ax2.plot(epochs_ran, history.history["val_accuracy"], label="Val", lw=2, color="#f97316", ls="--")
    ax2.set_title("Accuracy"); ax2.set_xlabel("Epoch"); ax2.set_ylabel("Accuracy")
    ax2.legend(); ax2.grid(alpha=0.3)
    fig.suptitle("AlexNet Training Summary", fontsize=15, fontweight="bold", y=1.02)
    fig.tight_layout()
    fig.savefig(os.path.join(out, "training_summary.png"), dpi=150, bbox_inches="tight")
    plt.show(); plt.close(fig)


def plot_confusion_matrix(results, config):
    out = os.path.join(config["output_dir"], "plots")
    ensure_dir(out)
    cm = np.array(results["confusion_matrix"])
    class_names = config["class_names"]

    fig, ax = plt.subplots(figsize=(9, 7))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
                xticklabels=class_names, yticklabels=class_names,
                linewidths=0.5, linecolor="gray", ax=ax)
    ax.set_title("Confusion Matrix", fontsize=14, fontweight="bold")
    ax.set_ylabel("True Label"); ax.set_xlabel("Predicted Label")
    plt.xticks(rotation=35, ha="right"); plt.yticks(rotation=0)
    fig.tight_layout(); fig.savefig(os.path.join(out, "confusion_matrix.png"), dpi=150)
    plt.show(); plt.close(fig)

    # Normalized
    cm_norm = cm.astype("float") / cm.sum(axis=1, keepdims=True)
    fig, ax = plt.subplots(figsize=(9, 7))
    sns.heatmap(cm_norm, annot=True, fmt=".2f", cmap="YlOrRd",
                xticklabels=class_names, yticklabels=class_names,
                linewidths=0.5, linecolor="gray", ax=ax, vmin=0, vmax=1)
    ax.set_title("Normalized Confusion Matrix", fontsize=14, fontweight="bold")
    ax.set_ylabel("True Label"); ax.set_xlabel("Predicted Label")
    plt.xticks(rotation=35, ha="right"); plt.yticks(rotation=0)
    fig.tight_layout(); fig.savefig(os.path.join(out, "confusion_matrix_normalized.png"), dpi=150)
    plt.show(); plt.close(fig)

# %%
# ══════════════════════════════════════════════════════════════
# STAGE 8 — SAVE MODEL & RESULTS
# ══════════════════════════════════════════════════════════════

def save_everything(model, history, results, config):
    separator("STAGE 8 — SAVING ARTEFACTS")
    out = config["output_dir"]
    ensure_dir(out)

    # Full model
    model.save(os.path.join(out, "alexnet_final.keras"))
    print(f"  ✓ Final model saved")

    # Weights
    model.save_weights(os.path.join(out, "alexnet_weights.weights.h5"))
    print(f"  ✓ Weights saved")

    # Architecture JSON
    with open(os.path.join(out, "alexnet_architecture.json"), "w") as f:
        json.dump(json.loads(model.to_json()), f, indent=2)
    print(f"  ✓ Architecture JSON saved")

    # Training history
    hist_data = {k: [float(v) for v in vals] for k, vals in history.history.items()}
    with open(os.path.join(out, "training_history.json"), "w") as f:
        json.dump(hist_data, f, indent=2)
    print(f"  ✓ Training history saved")

    # Evaluation results
    with open(os.path.join(out, "evaluation_results.json"), "w") as f:
        json.dump(results, f, indent=2)
    print(f"  ✓ Evaluation results saved")

    # Config snapshot
    config_safe = {k: v for k, v in config.items()}
    config_safe["timestamp"] = datetime.datetime.now().isoformat()
    with open(os.path.join(out, "config_snapshot.json"), "w") as f:
        json.dump(config_safe, f, indent=2)
    print(f"  ✓ Config snapshot saved")

# %%
# ══════════════════════════════════════════════════════════════
# MAIN PIPELINE
# ══════════════════════════════════════════════════════════════

def main():
    print("╔══════════════════════════════════════════════════════════════╗")
    print("║  VGG 16 — Dementia MRI Classification (Colab + GPU)       ║")
    print("║  5 Classes · 224×224 · TensorFlow/Keras                    ║")
    print("╚══════════════════════════════════════════════════════════════╝")

    set_seeds(CONFIG["seed"])

    # GPU check
    gpus = tf.config.list_physical_devices("GPU")
    print(f"\n  TensorFlow : {tf.__version__}")
    print(f"  GPUs       : {len(gpus)}")
    for g in gpus: print(f"    • {g.name}")

    # Run pipeline
    inspection = inspect_dataset(CONFIG)
    perform_eda(CONFIG, inspection)
    train_gen, valid_gen = create_data_generators(CONFIG)
    model = build_vgg16(CONFIG)
    history = compile_and_train(model, train_gen, valid_gen, CONFIG)
    results = evaluate_model(model, valid_gen, CONFIG)
    plot_training_curves(history, CONFIG)
    plot_confusion_matrix(results, CONFIG)
    save_everything(model, history, results, CONFIG)

    separator("PIPELINE COMPLETE")
    print(f"  Final Test Accuracy : {results['test_accuracy']*100:.2f}%")
    print(f"  Final Test Loss     : {results['test_loss']:.4f}")
    print(f"  All outputs saved to: {CONFIG['output_dir']}")

if __name__ == "__main__":
    main()
# Out:
# ╔══════════════════════════════════════════════════════════════╗
# ║  VGG 16 — Dementia MRI Classification (Colab + GPU)       ║
# ║  5 Classes · 224×224 · TensorFlow/Keras                    ║
# ╚══════════════════════════════════════════════════════════════╝
#
#   TensorFlow : 2.19.0
#   GPUs       : 1
#     • /physical_device:GPU:0
#
# ════════════════════════════════════════════════════════════════════════
#   STAGE 1 — DATASET INSPECTION
# ════════════════════════════════════════════════════════════════════════
#
#   Split: train
#   Class                      Count         %
#   ------------------------------------------
#   Mild-Demented               1000     20.0%
#   Moderate-Demented           1000     20.0%
#   Non-Demented                1000     20.0%
#   Severe-Demented             1000     20.0%
#   Very-Mild-Demented          1000     20.0%
#   TOTAL                       5000
#
#   Split: valid
#   Class                      Count         %
#   ------------------------------------------
#   Mild-Demented                293     33.7%
#   Moderate-Demented            239     27.5%
#   Non-Demented                 192     22.1%
#   Severe-Demented                4      0.5%
#   Very-Mild-Demented           142     16.3%
#   TOTAL                        870
#
# ════════════════════════════════════════════════════════════════════════
#   STAGE 2 — EDA
# ════════════════════════════════════════════════════════════════════════
# ════════════════════════════════════════════════════════════════════════
#   STAGE 3 — DATA LOADING
# ════════════════════════════════════════════════════════════════════════
# Found 5000 images belonging to 5 classes.
# Found 870 images belonging to 5 classes.
#   Train batches/epoch : 157
#   Valid batches/epoch : 28
#   Class indices       : {'Mild-Demented': 0, 'Moderate-Demented': 1, 'Non-Demented': 2, 'Severe-Demented': 3, 'Very-Mild-Demented': 4}
#
# ════════════════════════════════════════════════════════════════════════
#   STAGE 4 — VGG-16 ARCHITECTURE
# ════════════════════════════════════════════════════════════════════════
# Model: "VGG16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_image (InputLayer)        │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_bn1 (BatchNormalization) │ (None, 224, 224, 64)   │           256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_relu1 (Activation)       │ (None, 224, 224, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 224, 224, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_bn2 (BatchNormalization) │ (None, 224, 224, 64)   │           256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_relu2 (Activation)       │ (None, 224, 224, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 112, 112, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_bn1 (BatchNormalization) │ (None, 112, 112, 128)  │           512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_relu1 (Activation)       │ (None, 112, 112, 128)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 112, 112, 128)  │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_bn2 (BatchNormalization) │ (None, 112, 112, 128)  │           512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_relu2 (Activation)       │ (None, 112, 112, 128)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 56, 56, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_bn1 (BatchNormalization) │ (None, 56, 56, 256)    │         1,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_relu1 (Activation)       │ (None, 56, 56, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_bn2 (BatchNormalization) │ (None, 56, 56, 256)    │         1,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_relu2 (Activation)       │ (None, 56, 56, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_bn3 (BatchNormalization) │ (None, 56, 56, 256)    │         1,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_relu3 (Activation)       │ (None, 56, 56, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 28, 28, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_bn1 (BatchNormalization) │ (None, 28, 28, 512)    │         2,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_relu1 (Activation)       │ (None, 28, 28, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_bn2 (BatchNormalization) │ (None, 28, 28, 512)    │         2,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_relu2 (Activation)       │ (None, 28, 28, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_bn3 (BatchNormalization) │ (None, 28, 28, 512)    │         2,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_relu3 (Activation)       │ (None, 28, 28, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_bn1 (BatchNormalization) │ (None, 14, 14, 512)    │         2,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_relu1 (Activation)       │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_bn2 (BatchNormalization) │ (None, 14, 14, 512)    │         2,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_relu2 (Activation)       │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_bn3 (BatchNormalization) │ (None, 14, 14, 512)    │         2,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_relu3 (Activation)       │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 7, 7, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 25088)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fc1 (Dense)                     │ (None, 4096)           │   102,764,544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bn_fc1 (BatchNormalization)     │ (None, 4096)           │        16,384 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ relu_fc1 (Activation)           │ (None, 4096)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ drop1 (Dropout)                 │ (None, 4096)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fc2 (Dense)                     │ (None, 4096)           │    16,781,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bn_fc2 (BatchNormalization)     │ (None, 4096)           │        16,384 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ relu_fc2 (Activation)           │ (None, 4096)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ drop2 (Dropout)                 │ (None, 4096)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ predictions (Dense)             │ (None, 5)              │        20,485 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 134,330,693 (512.43 MB)
#  Trainable params: 134,305,861 (512.34 MB)
#  Non-trainable params: 24,832 (97.00 KB)
# ════════════════════════════════════════════════════════════════════════
#   STAGE 5 — TRAINING
# ════════════════════════════════════════════════════════════════════════
#   Class weights: {0: np.float64(1.0), 1: np.float64(1.0), 2: np.float64(1.0), 3: np.float64(1.0), 4: np.float64(1.0)}
#   Optimizer : AdamW (lr=0.001, wd=0.0005)
#   Loss      : CCE (label_smoothing=0.1)
#   Epochs    : 100 (max), Batch: 32
# Epoch 1/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 699ms/step - accuracy: 0.6012 - loss: 10.2847
# Epoch 1: val_loss improved from None to 8.65209, saving model to /content/drive/MyDrive/OUTPUT/best_model.keras
#
# Epoch 1: finished saving model to /content/drive/MyDrive/OUTPUT/best_model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 531s 3s/step - accuracy: 0.7268 - loss: 9.3327 - val_accuracy: 0.3632 - val_loss: 8.6521 - learning_rate: 0.0010
# Epoch 2/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 541ms/step - accuracy: 0.8484 - loss: 6.5044
# Epoch 2: val_loss did not improve from 8.65209
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 91s 578ms/step - accuracy: 0.8536 - loss: 5.8331 - val_accuracy: 0.0046 - val_loss: 55.6091 - learning_rate: 0.0010
# Epoch 3/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 565ms/step - accuracy: 0.8741 - loss: 4.2180
# Epoch 3: val_loss improved from 8.65209 to 6.09937, saving model to /content/drive/MyDrive/OUTPUT/best_model.keras
#
# Epoch 3: finished saving model to /content/drive/MyDrive/OUTPUT/best_model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 110s 699ms/step - accuracy: 0.8620 - loss: 3.9070 - val_accuracy: 0.0218 - val_loss: 6.0994 - learning_rate: 0.0010
# Epoch 4/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 811ms/step - accuracy: 0.8699 - loss: 3.0748
# Epoch 4: val_loss improved from 6.09937 to 4.27406, saving model to /content/drive/MyDrive/OUTPUT/best_model.keras
#
# Epoch 4: finished saving model to /content/drive/MyDrive/OUTPUT/best_model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 151s 960ms/step - accuracy: 0.8664 - loss: 2.9067 - val_accuracy: 0.3793 - val_loss: 4.2741 - learning_rate: 0.0010
# Epoch 5/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 815ms/step - accuracy: 0.8730 - loss: 2.5518
# Epoch 5: val_loss improved from 4.27406 to 4.15123, saving model to /content/drive/MyDrive/OUTPUT/best_model.keras
#
# Epoch 5: finished saving model to /content/drive/MyDrive/OUTPUT/best_model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 150s 953ms/step - accuracy: 0.8822 - loss: 2.3997 - val_accuracy: 0.6966 - val_loss: 4.1512 - learning_rate: 0.0010
# Epoch 6/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 800ms/step - accuracy: 0.8865 - loss: 2.1438
# Epoch 6: val_loss improved from 4.15123 to 1.98735, saving model to /content/drive/MyDrive/OUTPUT/best_model.keras
#
# Epoch 6: finished saving model to /content/drive/MyDrive/OUTPUT/best_model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 145s 924ms/step - accuracy: 0.8792 - loss: 2.0981 - val_accuracy: 0.8356 - val_loss: 1.9874 - learning_rate: 0.0010
# Epoch 7/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 813ms/step - accuracy: 0.8799 - loss: 1.9819
# Epoch 7: val_loss improved from 1.98735 to 1.72714, saving model to /content/drive/MyDrive/OUTPUT/best_model.keras
#
# Epoch 7: finished saving model to /content/drive/MyDrive/OUTPUT/best_model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 151s 964ms/step - accuracy: 0.8864 - loss: 1.8881 - val_accuracy: 0.8563 - val_loss: 1.7271 - learning_rate: 0.0010
# Epoch 8/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 819ms/step - accuracy: 0.8937 - loss: 1.7335
# Epoch 8: val_loss did not improve from 1.72714
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 135s 861ms/step - accuracy: 0.8822 - loss: 1.7665 - val_accuracy: 0.8138 - val_loss: 1.7796 - learning_rate: 0.0010
# Epoch 9/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 575ms/step - accuracy: 0.8922 - loss: 1.6549
# Epoch 9: val_loss did not improve from 1.72714
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 96s 612ms/step - accuracy: 0.8752 - loss: 1.7055 - val_accuracy: 0.3345 - val_loss: 3.2442 - learning_rate: 0.0010
# Epoch 10/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 588ms/step - accuracy: 0.8705 - loss: 1.8822
# Epoch 10: val_loss did not improve from 1.72714
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 98s 624ms/step - accuracy: 0.8724 - loss: 1.8803 - val_accuracy: 0.8414 - val_loss: 1.7678 - learning_rate: 0.0010
# Epoch 11/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 566ms/step - accuracy: 0.9048 - loss: 1.6180
# Epoch 11: val_loss did not improve from 1.72714
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 139s 604ms/step - accuracy: 0.9002 - loss: 1.5744 - val_accuracy: 0.5874 - val_loss: 1.9014 - learning_rate: 0.0010
# Epoch 12/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 583ms/step - accuracy: 0.8860 - loss: 1.5687
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 12: val_loss did not improve from 1.72714
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 97s 619ms/step - accuracy: 0.8876 - loss: 1.6416 - val_accuracy: 0.4149 - val_loss: 2.7506 - learning_rate: 0.0010
# Epoch 13/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 592ms/step - accuracy: 0.9205 - loss: 1.4203
# Epoch 13: val_loss did not improve from 1.72714
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 99s 628ms/step - accuracy: 0.9228 - loss: 1.3209 - val_accuracy: 0.4632 - val_loss: 1.9782 - learning_rate: 5.0000e-04
# Epoch 14/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 591ms/step - accuracy: 0.9282 - loss: 1.1399
# Epoch 14: val_loss improved from 1.72714 to 1.51959, saving model to /content/drive/MyDrive/OUTPUT/best_model.keras
#
# Epoch 14: finished saving model to /content/drive/MyDrive/OUTPUT/best_model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 126s 805ms/step - accuracy: 0.9276 - loss: 1.1199 - val_accuracy: 0.6621 - val_loss: 1.5196 - learning_rate: 5.0000e-04
# Epoch 15/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 820ms/step - accuracy: 0.9088 - loss: 1.1350
# Epoch 15: val_loss improved from 1.51959 to 1.06527, saving model to /content/drive/MyDrive/OUTPUT/best_model.keras
#
# Epoch 15: finished saving model to /content/drive/MyDrive/OUTPUT/best_model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 158s 1s/step - accuracy: 0.9168 - loss: 1.1093 - val_accuracy: 0.8920 - val_loss: 1.0653 - learning_rate: 5.0000e-04
# Epoch 16/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 811ms/step - accuracy: 0.9338 - loss: 1.0491
# Epoch 16: val_loss did not improve from 1.06527
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 133s 849ms/step - accuracy: 0.9234 - loss: 1.0762 - val_accuracy: 0.5391 - val_loss: 1.6561 - learning_rate: 5.0000e-04
# Epoch 17/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 575ms/step - accuracy: 0.9192 - loss: 1.0748
# Epoch 17: val_loss did not improve from 1.06527
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 96s 612ms/step - accuracy: 0.9220 - loss: 1.0788 - val_accuracy: 0.7655 - val_loss: 1.2919 - learning_rate: 5.0000e-04
# Epoch 18/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 590ms/step - accuracy: 0.9212 - loss: 1.0420
# Epoch 18: val_loss did not improve from 1.06527
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 99s 628ms/step - accuracy: 0.9300 - loss: 1.0170 - val_accuracy: 0.8069 - val_loss: 1.1310 - learning_rate: 5.0000e-04
# Epoch 19/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 595ms/step - accuracy: 0.9237 - loss: 0.9866
# Epoch 19: val_loss did not improve from 1.06527
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 100s 636ms/step - accuracy: 0.9218 - loss: 1.0097 - val_accuracy: 0.8368 - val_loss: 1.4212 - learning_rate: 5.0000e-04
# Epoch 20/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 590ms/step - accuracy: 0.9080 - loss: 1.0804
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 20: val_loss did not improve from 1.06527
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 100s 635ms/step - accuracy: 0.9142 - loss: 1.0447 - val_accuracy: 0.8506 - val_loss: 1.0862 - learning_rate: 5.0000e-04
# Epoch 21/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 593ms/step - accuracy: 0.9339 - loss: 0.9474
# Epoch 21: val_loss did not improve from 1.06527
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 104s 659ms/step - accuracy: 0.9382 - loss: 0.9006 - val_accuracy: 0.6253 - val_loss: 1.5001 - learning_rate: 2.5000e-04
# Epoch 22/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 591ms/step - accuracy: 0.9429 - loss: 0.8311
# Epoch 22: val_loss improved from 1.06527 to 0.83228, saving model to /content/drive/MyDrive/OUTPUT/best_model.keras
#
# Epoch 22: finished saving model to /content/drive/MyDrive/OUTPUT/best_model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 127s 809ms/step - accuracy: 0.9430 - loss: 0.8185 - val_accuracy: 0.9103 - val_loss: 0.8323 - learning_rate: 2.5000e-04
# Epoch 23/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 820ms/step - accuracy: 0.9528 - loss: 0.7832
# Epoch 23: val_loss did not improve from 0.83228
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 135s 856ms/step - accuracy: 0.9478 - loss: 0.7913 - val_accuracy: 0.8885 - val_loss: 0.8771 - learning_rate: 2.5000e-04
# Epoch 24/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 580ms/step - accuracy: 0.9445 - loss: 0.7764
# Epoch 24: val_loss did not improve from 0.83228
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 97s 617ms/step - accuracy: 0.9394 - loss: 0.7922 - val_accuracy: 0.4483 - val_loss: 2.7289 - learning_rate: 2.5000e-04
# Epoch 25/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 591ms/step - accuracy: 0.9417 - loss: 0.8170
# Epoch 25: val_loss did not improve from 0.83228
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 99s 630ms/step - accuracy: 0.9398 - loss: 0.8258 - val_accuracy: 0.7977 - val_loss: 1.1136 - learning_rate: 2.5000e-04
# Epoch 26/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 591ms/step - accuracy: 0.9152 - loss: 0.8813
# Epoch 26: val_loss did not improve from 0.83228
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 100s 633ms/step - accuracy: 0.9366 - loss: 0.8383 - val_accuracy: 0.8851 - val_loss: 0.8802 - learning_rate: 2.5000e-04
# Epoch 27/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 593ms/step - accuracy: 0.9456 - loss: 0.8107
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 27: val_loss did not improve from 0.83228
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 100s 635ms/step - accuracy: 0.9358 - loss: 0.8356 - val_accuracy: 0.8023 - val_loss: 1.0866 - learning_rate: 2.5000e-04
# Epoch 28/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 592ms/step - accuracy: 0.9588 - loss: 0.7544
# Epoch 28: val_loss did not improve from 0.83228
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 100s 635ms/step - accuracy: 0.9596 - loss: 0.7420 - val_accuracy: 0.8759 - val_loss: 0.8723 - learning_rate: 1.2500e-04
# Epoch 29/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 590ms/step - accuracy: 0.9654 - loss: 0.6962
# Epoch 29: val_loss did not improve from 0.83228
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 99s 631ms/step - accuracy: 0.9626 - loss: 0.7107 - val_accuracy: 0.7989 - val_loss: 1.0242 - learning_rate: 1.2500e-04
# Epoch 30/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 592ms/step - accuracy: 0.9656 - loss: 0.6942
# Epoch 30: val_loss improved from 0.83228 to 0.81370, saving model to /content/drive/MyDrive/OUTPUT/best_model.keras
#
# Epoch 30: finished saving model to /content/drive/MyDrive/OUTPUT/best_model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 121s 767ms/step - accuracy: 0.9664 - loss: 0.6885 - val_accuracy: 0.8862 - val_loss: 0.8137 - learning_rate: 1.2500e-04
# Epoch 31/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 821ms/step - accuracy: 0.9680 - loss: 0.6699
# Epoch 31: val_loss improved from 0.81370 to 0.77641, saving model to /content/drive/MyDrive/OUTPUT/best_model.keras
#
# Epoch 31: finished saving model to /content/drive/MyDrive/OUTPUT/best_model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 156s 997ms/step - accuracy: 0.9624 - loss: 0.6759 - val_accuracy: 0.9126 - val_loss: 0.7764 - learning_rate: 1.2500e-04
# Epoch 32/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 819ms/step - accuracy: 0.9604 - loss: 0.6694
# Epoch 32: val_loss did not improve from 0.77641
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 134s 855ms/step - accuracy: 0.9640 - loss: 0.6590 - val_accuracy: 0.7862 - val_loss: 1.0224 - learning_rate: 1.2500e-04
# Epoch 33/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 577ms/step - accuracy: 0.9621 - loss: 0.6667
# Epoch 33: val_loss did not improve from 0.77641
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 97s 616ms/step - accuracy: 0.9606 - loss: 0.6733 - val_accuracy: 0.8805 - val_loss: 0.8481 - learning_rate: 1.2500e-04
# Epoch 34/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 590ms/step - accuracy: 0.9659 - loss: 0.6760
# Epoch 34: val_loss did not improve from 0.77641
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 99s 632ms/step - accuracy: 0.9610 - loss: 0.6841 - val_accuracy: 0.9092 - val_loss: 0.7795 - learning_rate: 1.2500e-04
# Epoch 35/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 590ms/step - accuracy: 0.9615 - loss: 0.6688
# Epoch 35: val_loss improved from 0.77641 to 0.76198, saving model to /content/drive/MyDrive/OUTPUT/best_model.keras
#
# Epoch 35: finished saving model to /content/drive/MyDrive/OUTPUT/best_model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 118s 753ms/step - accuracy: 0.9656 - loss: 0.6641 - val_accuracy: 0.9103 - val_loss: 0.7620 - learning_rate: 1.2500e-04
# Epoch 36/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 822ms/step - accuracy: 0.9680 - loss: 0.6561
# Epoch 36: val_loss did not improve from 0.76198
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 135s 859ms/step - accuracy: 0.9622 - loss: 0.6631 - val_accuracy: 0.9069 - val_loss: 0.8010 - learning_rate: 1.2500e-04
# Epoch 37/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 580ms/step - accuracy: 0.9697 - loss: 0.6306
# Epoch 37: val_loss improved from 0.76198 to 0.75598, saving model to /content/drive/MyDrive/OUTPUT/best_model.keras
#
# Epoch 37: finished saving model to /content/drive/MyDrive/OUTPUT/best_model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 113s 718ms/step - accuracy: 0.9690 - loss: 0.6324 - val_accuracy: 0.9080 - val_loss: 0.7560 - learning_rate: 1.2500e-04
# Epoch 38/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 833ms/step - accuracy: 0.9762 - loss: 0.6103
# Epoch 38: val_loss did not improve from 0.75598
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 137s 875ms/step - accuracy: 0.9708 - loss: 0.6230 - val_accuracy: 0.8230 - val_loss: 1.0678 - learning_rate: 1.2500e-04
# Epoch 39/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 579ms/step - accuracy: 0.9659 - loss: 0.6284
# Epoch 39: val_loss did not improve from 0.75598
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 97s 617ms/step - accuracy: 0.9616 - loss: 0.6440 - val_accuracy: 0.7759 - val_loss: 1.1079 - learning_rate: 1.2500e-04
# Epoch 40/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 564ms/step - accuracy: 0.9702 - loss: 0.6446
# Epoch 40: val_loss did not improve from 0.75598
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 140s 606ms/step - accuracy: 0.9666 - loss: 0.6496 - val_accuracy: 0.8552 - val_loss: 0.8926 - learning_rate: 1.2500e-04
# Epoch 41/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 582ms/step - accuracy: 0.9652 - loss: 0.6480
# Epoch 41: val_loss did not improve from 0.75598
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 98s 621ms/step - accuracy: 0.9648 - loss: 0.6587 - val_accuracy: 0.9046 - val_loss: 0.7832 - learning_rate: 1.2500e-04
# Epoch 42/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 592ms/step - accuracy: 0.9769 - loss: 0.6270
# Epoch 42: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 42: val_loss did not improve from 0.75598
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 99s 631ms/step - accuracy: 0.9712 - loss: 0.6331 - val_accuracy: 0.8966 - val_loss: 0.7776 - learning_rate: 1.2500e-04
# Epoch 43/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 568ms/step - accuracy: 0.9732 - loss: 0.6121
# Epoch 43: val_loss improved from 0.75598 to 0.73089, saving model to /content/drive/MyDrive/OUTPUT/best_model.keras
#
# Epoch 43: finished saving model to /content/drive/MyDrive/OUTPUT/best_model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 156s 725ms/step - accuracy: 0.9786 - loss: 0.5963 - val_accuracy: 0.9092 - val_loss: 0.7309 - learning_rate: 6.2500e-05
# Epoch 44/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 556ms/step - accuracy: 0.9879 - loss: 0.5651
# Epoch 44: val_loss did not improve from 0.73089
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 148s 592ms/step - accuracy: 0.9838 - loss: 0.5691 - val_accuracy: 0.8356 - val_loss: 0.9153 - learning_rate: 6.2500e-05
# Epoch 45/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 578ms/step - accuracy: 0.9864 - loss: 0.5583
# Epoch 45: val_loss did not improve from 0.73089
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 97s 619ms/step - accuracy: 0.9848 - loss: 0.5637 - val_accuracy: 0.9057 - val_loss: 0.7349 - learning_rate: 6.2500e-05
# Epoch 46/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 589ms/step - accuracy: 0.9888 - loss: 0.5486
# Epoch 46: val_loss did not improve from 0.73089
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 99s 631ms/step - accuracy: 0.9868 - loss: 0.5527 - val_accuracy: 0.8920 - val_loss: 0.7887 - learning_rate: 6.2500e-05
# Epoch 47/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 593ms/step - accuracy: 0.9843 - loss: 0.5607
# Epoch 47: val_loss did not improve from 0.73089
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 100s 637ms/step - accuracy: 0.9824 - loss: 0.5644 - val_accuracy: 0.9092 - val_loss: 0.7413 - learning_rate: 6.2500e-05
# Epoch 48/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 591ms/step - accuracy: 0.9880 - loss: 0.5469
# Epoch 48: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 48: val_loss did not improve from 0.73089
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 100s 634ms/step - accuracy: 0.9882 - loss: 0.5423 - val_accuracy: 0.9034 - val_loss: 0.7712 - learning_rate: 6.2500e-05
# Epoch 49/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 594ms/step - accuracy: 0.9897 - loss: 0.5317
# Epoch 49: val_loss improved from 0.73089 to 0.71389, saving model to /content/drive/MyDrive/OUTPUT/best_model.keras
#
# Epoch 49: finished saving model to /content/drive/MyDrive/OUTPUT/best_model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 124s 790ms/step - accuracy: 0.9892 - loss: 0.5347 - val_accuracy: 0.9230 - val_loss: 0.7139 - learning_rate: 3.1250e-05
# Epoch 50/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 831ms/step - accuracy: 0.9877 - loss: 0.5370
# Epoch 50: val_loss did not improve from 0.71389
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 137s 874ms/step - accuracy: 0.9906 - loss: 0.5288 - val_accuracy: 0.9080 - val_loss: 0.7352 - learning_rate: 3.1250e-05
# Epoch 51/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 578ms/step - accuracy: 0.9919 - loss: 0.5199
# Epoch 51: val_loss improved from 0.71389 to 0.69025, saving model to /content/drive/MyDrive/OUTPUT/best_model.keras
#
# Epoch 51: finished saving model to /content/drive/MyDrive/OUTPUT/best_model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 138s 881ms/step - accuracy: 0.9938 - loss: 0.5163 - val_accuracy: 0.9103 - val_loss: 0.6902 - learning_rate: 3.1250e-05
# Epoch 52/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 810ms/step - accuracy: 0.9949 - loss: 0.5080
# Epoch 52: val_loss improved from 0.69025 to 0.68398, saving model to /content/drive/MyDrive/OUTPUT/best_model.keras
#
# Epoch 52: finished saving model to /content/drive/MyDrive/OUTPUT/best_model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 153s 976ms/step - accuracy: 0.9958 - loss: 0.5054 - val_accuracy: 0.9207 - val_loss: 0.6840 - learning_rate: 3.1250e-05
# Epoch 53/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 812ms/step - accuracy: 0.9957 - loss: 0.5056
# Epoch 53: val_loss did not improve from 0.68398
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 134s 855ms/step - accuracy: 0.9942 - loss: 0.5087 - val_accuracy: 0.9046 - val_loss: 0.7391 - learning_rate: 3.1250e-05
# Epoch 54/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 577ms/step - accuracy: 0.9902 - loss: 0.5164
# Epoch 54: val_loss did not improve from 0.68398
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 97s 615ms/step - accuracy: 0.9926 - loss: 0.5109 - val_accuracy: 0.9103 - val_loss: 0.7127 - learning_rate: 3.1250e-05
# Epoch 55/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 590ms/step - accuracy: 0.9960 - loss: 0.5020
# Epoch 55: val_loss improved from 0.68398 to 0.67378, saving model to /content/drive/MyDrive/OUTPUT/best_model.keras
#
# Epoch 55: finished saving model to /content/drive/MyDrive/OUTPUT/best_model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 125s 794ms/step - accuracy: 0.9958 - loss: 0.5011 - val_accuracy: 0.9253 - val_loss: 0.6738 - learning_rate: 3.1250e-05
# Epoch 56/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 822ms/step - accuracy: 0.9961 - loss: 0.4985
# Epoch 56: val_loss did not improve from 0.67378
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 135s 861ms/step - accuracy: 0.9968 - loss: 0.4956 - val_accuracy: 0.9241 - val_loss: 0.6819 - learning_rate: 3.1250e-05
# Epoch 57/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 580ms/step - accuracy: 0.9968 - loss: 0.4924
# Epoch 57: val_loss did not improve from 0.67378
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 97s 617ms/step - accuracy: 0.9962 - loss: 0.4934 - val_accuracy: 0.9138 - val_loss: 0.6960 - learning_rate: 3.1250e-05
# Epoch 58/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 591ms/step - accuracy: 0.9953 - loss: 0.4931
# Epoch 58: val_loss did not improve from 0.67378
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 99s 628ms/step - accuracy: 0.9968 - loss: 0.4897 - val_accuracy: 0.9138 - val_loss: 0.7121 - learning_rate: 3.1250e-05
# Epoch 59/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 593ms/step - accuracy: 0.9971 - loss: 0.4887
# Epoch 59: val_loss did not improve from 0.67378
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 99s 632ms/step - accuracy: 0.9942 - loss: 0.4925 - val_accuracy: 0.9207 - val_loss: 0.6899 - learning_rate: 3.1250e-05
# Epoch 60/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 592ms/step - accuracy: 0.9961 - loss: 0.4951
# Epoch 60: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 60: val_loss did not improve from 0.67378
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 100s 633ms/step - accuracy: 0.9954 - loss: 0.4941 - val_accuracy: 0.9092 - val_loss: 0.6859 - learning_rate: 3.1250e-05
# Epoch 61/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 594ms/step - accuracy: 0.9967 - loss: 0.4891
# Epoch 61: val_loss did not improve from 0.67378
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 100s 636ms/step - accuracy: 0.9970 - loss: 0.4878 - val_accuracy: 0.9149 - val_loss: 0.6750 - learning_rate: 1.5625e-05
# Epoch 62/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 594ms/step - accuracy: 0.9988 - loss: 0.4806
# Epoch 62: val_loss did not improve from 0.67378
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 100s 637ms/step - accuracy: 0.9992 - loss: 0.4791 - val_accuracy: 0.9161 - val_loss: 0.6867 - learning_rate: 1.5625e-05
# Epoch 63/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 593ms/step - accuracy: 0.9987 - loss: 0.4782
# Epoch 63: val_loss did not improve from 0.67378
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 99s 632ms/step - accuracy: 0.9990 - loss: 0.4777 - val_accuracy: 0.9172 - val_loss: 0.7011 - learning_rate: 1.5625e-05
# Epoch 64/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 593ms/step - accuracy: 0.9988 - loss: 0.4768
# Epoch 64: val_loss improved from 0.67378 to 0.67224, saving model to /content/drive/MyDrive/OUTPUT/best_model.keras
#
# Epoch 64: finished saving model to /content/drive/MyDrive/OUTPUT/best_model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 132s 843ms/step - accuracy: 0.9978 - loss: 0.4774 - val_accuracy: 0.9184 - val_loss: 0.6722 - learning_rate: 1.5625e-05
# Epoch 65/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 836ms/step - accuracy: 0.9971 - loss: 0.4800
# Epoch 65: val_loss did not improve from 0.67224
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 142s 902ms/step - accuracy: 0.9972 - loss: 0.4796 - val_accuracy: 0.9218 - val_loss: 0.6842 - learning_rate: 1.5625e-05
# Epoch 66/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 577ms/step - accuracy: 0.9973 - loss: 0.4814
# Epoch 66: val_loss improved from 0.67224 to 0.64117, saving model to /content/drive/MyDrive/OUTPUT/best_model.keras
#
# Epoch 66: finished saving model to /content/drive/MyDrive/OUTPUT/best_model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 123s 786ms/step - accuracy: 0.9968 - loss: 0.4816 - val_accuracy: 0.9345 - val_loss: 0.6412 - learning_rate: 1.5625e-05
# Epoch 67/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 846ms/step - accuracy: 0.9988 - loss: 0.4743
# Epoch 67: val_loss did not improve from 0.64117
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 139s 883ms/step - accuracy: 0.9988 - loss: 0.4741 - val_accuracy: 0.9333 - val_loss: 0.6537 - learning_rate: 1.5625e-05
# Epoch 68/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 576ms/step - accuracy: 0.9997 - loss: 0.4698
# Epoch 68: val_loss did not improve from 0.64117
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 97s 619ms/step - accuracy: 0.9988 - loss: 0.4714 - val_accuracy: 0.9253 - val_loss: 0.6694 - learning_rate: 1.5625e-05
# Epoch 69/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 589ms/step - accuracy: 0.9999 - loss: 0.4689
# Epoch 69: val_loss did not improve from 0.64117
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 99s 631ms/step - accuracy: 0.9998 - loss: 0.4680 - val_accuracy: 0.9287 - val_loss: 0.6539 - learning_rate: 1.5625e-05
# Epoch 70/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 594ms/step - accuracy: 0.9990 - loss: 0.4674
# Epoch 70: val_loss did not improve from 0.64117
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 104s 660ms/step - accuracy: 0.9994 - loss: 0.4669 - val_accuracy: 0.9195 - val_loss: 0.6600 - learning_rate: 1.5625e-05
# Epoch 71/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 592ms/step - accuracy: 0.9992 - loss: 0.4656
# Epoch 71: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
#
# Epoch 71: val_loss did not improve from 0.64117
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 100s 635ms/step - accuracy: 0.9972 - loss: 0.4695 - val_accuracy: 0.9264 - val_loss: 0.6650 - learning_rate: 1.5625e-05
# Epoch 72/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 592ms/step - accuracy: 0.9984 - loss: 0.4689
# Epoch 72: val_loss did not improve from 0.64117
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 100s 636ms/step - accuracy: 0.9984 - loss: 0.4679 - val_accuracy: 0.9322 - val_loss: 0.6510 - learning_rate: 7.8125e-06
# Epoch 73/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 591ms/step - accuracy: 0.9999 - loss: 0.4645
# Epoch 73: val_loss did not improve from 0.64117
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 99s 629ms/step - accuracy: 0.9994 - loss: 0.4650 - val_accuracy: 0.9264 - val_loss: 0.6554 - learning_rate: 7.8125e-06
# Epoch 74/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 593ms/step - accuracy: 0.9989 - loss: 0.4657
# Epoch 74: val_loss did not improve from 0.64117
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 99s 630ms/step - accuracy: 0.9994 - loss: 0.4643 - val_accuracy: 0.9264 - val_loss: 0.6496 - learning_rate: 7.8125e-06
# Epoch 75/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 593ms/step - accuracy: 0.9979 - loss: 0.4675
# Epoch 75: val_loss did not improve from 0.64117
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 99s 629ms/step - accuracy: 0.9986 - loss: 0.4649 - val_accuracy: 0.9299 - val_loss: 0.6576 - learning_rate: 7.8125e-06
# Epoch 76/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 565ms/step - accuracy: 0.9997 - loss: 0.4613
# Epoch 76: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
#
# Epoch 76: val_loss did not improve from 0.64117
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 137s 600ms/step - accuracy: 0.9994 - loss: 0.4615 - val_accuracy: 0.9253 - val_loss: 0.6546 - learning_rate: 7.8125e-06
# Epoch 77/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 587ms/step - accuracy: 0.9990 - loss: 0.4628
# Epoch 77: val_loss did not improve from 0.64117
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 98s 622ms/step - accuracy: 0.9992 - loss: 0.4621 - val_accuracy: 0.9310 - val_loss: 0.6458 - learning_rate: 3.9063e-06
# Epoch 78/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 595ms/step - accuracy: 0.9992 - loss: 0.4613
# Epoch 78: val_loss did not improve from 0.64117
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 99s 632ms/step - accuracy: 0.9992 - loss: 0.4607 - val_accuracy: 0.9310 - val_loss: 0.6476 - learning_rate: 3.9063e-06
# Epoch 78: early stopping
# Restoring model weights from the end of the best epoch: 66.
#
# ════════════════════════════════════════════════════════════════════════
#   STAGE 6 — EVALUATION
# ════════════════════════════════════════════════════════════════════════
#   Test Loss     : 0.6412
#   Test Accuracy : 0.9345  (93.45%)
#
#   Classification Report:
#                     precision    recall  f1-score   support
#
#      Mild-Demented     0.9540    0.8498    0.8989       293
#  Moderate-Demented     0.9832    0.9791    0.9811       239
#       Non-Demented     0.8186    0.9635    0.8852       192
#    Severe-Demented     1.0000    0.7500    0.8571         4
# Very-Mild-Demented     1.0000    1.0000    1.0000       142
#
#           accuracy                         0.9345       870
#          macro avg     0.9512    0.9085    0.9245       870
#       weighted avg     0.9399    0.9345    0.9348       870
#
#   Confusion Matrix:
# [[249   3  41   0   0]
#  [  5 234   0   0   0]
#  [  7   0 185   0   0]
#  [  0   1   0   3   0]
#  [  0   0   0   0 142]]
#
# ════════════════════════════════════════════════════════════════════════
#   STAGE 7 — VISUALIZATION
# ════════════════════════════════════════════════════════════════════════
# ════════════════════════════════════════════════════════════════════════
#   STAGE 8 — SAVING ARTEFACTS
# ════════════════════════════════════════════════════════════════════════
#   ✓ Final model saved
#   ✓ Weights saved
#   ✓ Architecture JSON saved
#   ✓ Training history saved
#   ✓ Evaluation results saved
#   ✓ Config snapshot saved
#
# ════════════════════════════════════════════════════════════════════════
#   PIPELINE COMPLETE
# ════════════════════════════════════════════════════════════════════════
#   Final Test Accuracy : 93.45%
#   Final Test Loss     : 0.6412
#   All outputs saved to: /content/drive/MyDrive/OUTPUT
